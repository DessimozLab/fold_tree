# %%
import sys
sys.path.append('../src')

# %%
import glob
import ete3
import pandas as pd
import os
import time
import json
import AFDB_tools, treescore , foldseek2tree , corecut
import colour
import numpy as np
import toytree
from matplotlib import pyplot as plt
from Bio import SeqIO
import toytree
import toyplot.svg

# %%
# %load_ext autoreload
# %autoreload 2

# %%
outfolder = '../examples/rrnpp_final/'

# %%
try:
    os.mkdir(outfolder +'structs/')
except:
    print('already exists')

#load the identifiers
with open(outfolder + 'identifiers.txt') as handle:
    identifiers = [ l.strip() for l in handle ]
notfound = [ AFDB_tools.grab_struct(uniID, outfolder+'structs/')  for uniID in identifiers ]
notfound = [ i for i in notfound if i]
with open(outfolder+'unmapped.txt', 'w') as simout:
    simout.write(json.dumps(notfound))
# Out:
# already exists
# Q5WC62
# Q5WBC1
# Q5WBM7
# Q5WBC1
# Q5WBV2
# A0A060LTA2
# A0A060LT68
# A0A060M1P9
# A0A060LXZ4
# A0A060M7R1
# A0A060LST4
# A0A060M707
# A0A060M7H6
# A0A0T6BSE8
# A0A291KW88
# A0A1C3SE68
# A0A1C3SHV4
# A0A0T6BQE4
# A0A0T6BTL7
# A0A291KK33
# A0A0J6EG35
# A0A0T6BPN4
# A0A0T6BJL1
# A0A1C3SAM2
# A0A0J6EBB4
# A0A0M5JM86
# A0A0M5JM41
# A0A0M4FS88
# A0A0M3RAQ7
# A0A8G1J9J6
# structure not found A0A8G1J9J6
# A8FF04
# A8FIQ8
# A8FIS5
# A8FC49
# A8FC58
# A8FCC6
# A8FDL3
# A8FCC6
# A0A8U0I9E3
# structure not found A0A8U0I9E3
# A0A8U0I987
# structure not found A0A8U0I987
# A0A8U0I6F7
# structure not found A0A8U0I6F7
# A0A5C0WME3
# A0A5C0WCZ0
# A0A5C0WEH4
# A0A1L6ZEG5
# A0A1L6ZIK7
# A0A5C0WCZ0
# A0A5K1KRS0
# A0A5K1KVV2
# Q6EZI3
# A0A6L8P236
# A0A6H3ABQ7
# A0A5B8PT60
# A0A5P9Y049
# A0A2H2WIM5
# A0A7D3Y3L0
# A0A0E1MKG4
# A0A5P9Y049
# A0A2K8U1H8
# A0A6I7EEE1
# A0A158RUN4
# A0A158RJR9
# C2NVB0
# C2P4I8
# C2P7P3
# C2Z018
# B7HXS4
# B7HZ83
# B7JU66
# B7JCU9
# Q74NU6
# Q735S3
# Q733Y4
# Q81AP3
# Q81E45
# Q81H01
# B7H8P5
# C2SX62
# C2SN31
# C2SUH0
# C2SDR3
# C2SDR3
# D8GX91
# D8H6E1
# Q631L1
# C2XMV1
# C2X867
# C2XKZ3
# C2XMT9
# B7IR85
# B7IZ99
# B7IKA1
# C2MH55
# C2MNK1
# C2R4H1
# B9J687
# B9ITP0
# B9IXA1
# C2UN53
# C2UNP6
# C2UMS1
# C2URQ9
# C2URM8
# C2URQ9
# C2V7X4
# C2VLE4
# C2VBZ6
# C2W1E6
# C2W2G4
# C2W4Q7
# C2WFW0
# A0A2I0RBA8
# C2WQI3
# C2WWI6
# A0A2S1AAB0
# A0A2S1AH59
# A7GPZ9
# A7GL11
# A7GMG1
# A7GVL1
# A7GUX4
# A7GVL1
# A7GLT2
# A7GME7
# A7GMG1
# A0A1W6AJG0
# A0A0B5S9W9
# A0A0B5SFU9
# A0A1W6AJ49
# A0A1W6AHD5
# C2PYQ9
# C2PSB6
# C2Y441
# A0A0B5SCI6
# A0A1W6AJ91
# A9VV35
# A9VI48
# A0A4P9F2M1
# A0A2H3MLQ5
# A0A2B6IC24
# A0A2C4XGM5
# C3AM19
# A0A2B4PBZ4
# C3AVH9
# A0A2B4PBZ4
# A0A2C4XGM5
# C3BPR2
# C3BVN4
# C3BGX2
# A0A1B1LIJ8
# A0A1S7FCY4
# A0A5P8FHV3
# A0A1B1LDW3
# A0A1B1LGZ2
# A0A1B1LG80
# A0A3S9TJ74
# A0A0K0QMT7
# Q6HME5
# A0A1C9C349
# A0A826H478
# A0A826GVE8
# A0A826GSW8
# J4A2B0
# A0A806HWZ5
# K0FRX4
# K0FS52
# C3FZQ2
# A0A193CMT3
# A0A193CXH4
# C3GX39
# C3HBU9
# C3ED03
# C3DW77
# C3DUD2
# C3DUD2
# C3DW77
# M1R499
# M1R499
# M1R4G2
# V5MJE8
# C2PI20
# C2PB77
# A0A5C1FMV7
# A0A5C1FPG1
# A0A0H3E6Y7
# A0A0H3E1H2
# A0A0H3E241
# A0A0H3E5A1
# A0A0H3DYI3
# A0A0H3DWJ6
# A0A0H3DWQ7
# A0A0H3DXL3
# A0A0H3E4S2
# A0A0H3E6Y0
# A0A0H3DVB7
# A0A8G0WHY4
# structure not found A0A8G0WHY4
# A0A8G0S8P0
# structure not found A0A8G0S8P0
# A0A8G0SBZ7
# structure not found A0A8G0SBZ7
# A0A8G0WGX4
# structure not found A0A8G0WGX4
# A0A8G0SBI0
# structure not found A0A8G0SBI0
# Q65FD0
# Q65FZ3
# Q65HV9
# Q65M77
# Q65FR7
# Q65LL9
# Q65MM8
# Q65GG8
# A0A6G7JFH7
# A0A6G7JEB2
# A0A6G7JLW6
# A0A6G7JL46
# A0A6G7JI56
# A0A6G7JD58
# A0A6G7JCZ0
# A0A6G7JF69
# E0TU98
# G4NWJ5
# G4NT83
# A0A7U4I121
# A0A7U4KSU1
# A0A8F9SS43
# structure not found A0A8F9SS43
# A0A7U5AUI0
# D4FV89
# D4G6U9
# A0A809FAL7
# A0A809FN58
# O32294
# O34930
# Q59HN8
# Q00828
# P45943
# P94415
# P71002
# P96649
# A0A6H0WEL2
# A0A6H0WP66
# A0A6H0WHW6
# A0A6H0WNI7
# A0A410WM21
# A0A410WJB9
# A0A410WJW3
# A0A8F8XXK4
# structure not found A0A8F8XXK4
# A0A4V7TJT2
# A0A8F6CXY3
# structure not found A0A8F6CXY3
# A0A8F6CY61
# structure not found A0A8F6CY61
# A0A8F6D7F8
# structure not found A0A8F6D7F8
# A0A2I5K1Q4
# A7ZAM5
# A7Z1I3
# A7Z3N2
# A7Z9V6
# S6G2L3
# S6FLB3
# I2C5I8
# I2C8V2
# A0A6H2JYQ3
# A0A6H2JMZ8
# A0A6H2JLZ9
# A0A6H2JMB5
# A0A8F9U323
# structure not found A0A8F9U323
# A0A345X4M7
# A0A345X4M7
# A0A7Z2FVU2
# A0A7Z2FZP5
# A0A7Z2J5F3
# A0A7Z2J5L5
# A0A8T9FLT2
# structure not found A0A8T9FLT2
# A0A8T9FAW3
# structure not found A0A8T9FAW3
# A0A6I7F7W7
# A0A6I7FCV5
# A0A6I7EWL3
# A0A6I7FF07
# A0A6I7F953
# A0A6I7FCJ6
# A0A6I7EX47
# A0A6I7F671
# A0A6I7F442
# A0A6I7FGZ0
# A0A6I7FCM9
# A0A6I7FCJ6
# A0A6I7F7F1
# A0A6I7FCM0
# A0A7G7UBL7
# A0A7G7UEF1
# A0A7G7U8K8
# A0A109WF09
# A0A0B4SDG1
# A0A0B4S7Z8
# A0A0B4S6J1
# A0A160IM77
# Q9K5S4
# Q9K6M3
# Q7AJX7
# Q9KBE1
# A0A856M8Z8
# A0A075LSN7
# A0A075LME0
# A0A1P8CWN8
# structure not found A0A1P8CWN8
# A0A4P8SHT2
# A0A6P1X321
# A0A7M1KSS6
# K8E6J0
# G9WIW9
# G9WIW9
# G9WIW9
# G9WIX1
# G9WIX1
# A0A5P2TVV6
# A0A387BG42
# A0A387B9W1
# A0A0B8R220
# A0A239XEA8
# Q8DYJ0
# A0A3P5Y8E1
# A0A6I6I7J9
# F5WXP8
# A0A239T000
# A0A3S4SG61
# A0A380KXM9
# A0A345VKN9
# C1CE45
# A0A4U9YQS3
# Q9A132
# Q9A103
# A0A5C4NZD7
# A0A859ENS0
# A0A7H8V064
# A0A2X3VKT6
# A0A0Z8EDW7
# A0A2I5KLF7
# G7SDC7
# G3FEJ7
# G3FEJ7
# F8LYE6
# Q5M4D0
# Q5M4L6
# A0A892RRK1
# structure not found A0A892RRK1
# C5WF66
# C0MFK1
# A0A7Z9D2C2
# A0A2X3SEZ5
# B4U262
# A0A1E1GA66
# A0A0X8GYF8
# A0A223CWR7
# A0A1Y0ILD2
# Q5WC17
# A0A060LXZ7
# D3G1N8
# D3G1X9
# D3FRW2
# A0A5B8ZBN8
# U5LGD2
# A0A1L3MMI7
# A0A068NGC1
# A0A158RI13
# C2P6P7
# Q72X97
# Q74NS7
# Q814S2
# Q81H37
# B7HFP8
# Q4V144
# B7IR03
# B9IRY3
# C2V3H4
# A7GV98
# A0A0B5S0K7
# A0A0D6T5D1
# A9VSE8
# A0A2C5MKZ3
# C3BSZ0
# A0A1C9BP84
# J3WZS8
# K0G150
# M1Q4T6
# A0A2B5PUZ1
# A0A3G6UTQ4
# A0A6F8TZ02
# A0A7Z2K673
# A0A8T9FD52
# structure not found A0A8T9FD52
# A0A5P9HT58
# A0A5P9HTJ6
# A0A5P9HJ48
# A0A248TIQ0
# Q9KBW0
# A0A2S1H643
# A0A2S1H643
# A0A7T2CVM3
# A0A8U0BHM5
# structure not found A0A8U0BHM5
# A0A1B3XVB9
# A0A223EHS4
# D5DDU4
# A0A6I6Q166
# A0A6I6UUP9
# A0A6I6UPZ1
# A0A7T6Z226
# A0A514LKS8
# D6XZW8
# A0A223KT34
# A0A6B9YH72
# A0A8G1DJH3
# structure not found A0A8G1DJH3
# A0A0X9W936
# A0A0B4RF84
# A0A143HEG3
# A0A0F7HM59
# A0A516GK55
# I9L4S7
# F9UT06
# A0A2R3JQ24
# A0A1W6N9K3
# A0A5B8TEE0
# A0A0X8UWJ2
# C1C9L4
# A0A0H2URV9
# A0A0H2UN31
# A0A0H2UPU6
# G0I7K9
# A0A2Z5U3H1
# A0A2I5KE12
# A0A2I5KE12
# G7SF00
# A0A8G1BB92
# structure not found A0A8G1BB92
# B4U0L0
# A0A6I6W9I7
# A0A1E1G9T9
# A0A410PQC2
# A0A7I8DRW5
# G2T485
# G2T485
# A0A7R7EHC0
# D4K1I0
# D4K1I0
# A0A7G9W468
# A0A8T8D6L7
# structure not found A0A8T8D6L7
# Q8R6S1
# D3T6U8
# D7ASA6
# C7RGK2
# K0J028
# A0A167UYA1
# A0A7U6HAZ2
# A0A6H3AJL9
# A0A2P0H9I7
# A0A7D4JF71
# A0A7D3YVT9
# A0A6M8D843
# A0A7D4BZ44
# A0A2R2IP40
# A0A6I7EBT2
# A0A7D4C5X7
# A0A7D3Y9S7
# A0A5B8PSY4
# A0A2B0KN76
# A0A158RMJ1
# C2P7B9
# C2ZG98
# B7HM99
# B7JTX9
# B7H5Q3
# C2SZM6
# C2SD77
# C2RY88
# C2RY88
# C2NRY6
# D8HAH8
# C2XM02
# C2XDJ3
# B7IY66
# B9J6N4
# C2UMT0
# C2VL16
# C2X036
# C2X5G2
# A0A2S1AHN8
# A7GRV1
# A0A1W6AID9
# A0A1W6AHL6
# C2PQH4
# C2PY33
# A0A4P9EVU0
# A0A387A8Y1
# A0A7T3MNG3
# A0A1B1LI23
# A0A2B4JJM4
# A0A1B1LIA5
# A0A1B1LIV8
# A0A0K0QCL2
# A0A1B1KZE3
# A0A387A675
# A0A1S7FG60
# Q5LKC1
# A0A1C9C3A8
# J7HY14
# J4A2D0
# J7I1B6
# A0A806HXU6
# K0G6P9
# K0FZK1
# K0FM26
# K0FM26
# K0FYC4
# K0FX73
# C3GC51
# A0A193CZM6
# A0A193D294
# A0A193CMZ1
# C3ECN1
# C3EEB6
# C3DY65
# C3GSN6
# C3DP37
# C3DV05
# C3DEC5
# C3DQ44
# C3DVK3
# M1QXW8
# V5MLF0
# V5ME49
# V5MKJ5
# V5MM16
# A0A7D4F9I6
# A0A679H258
# A0A679GZ89
# A0A5C1FEK2
# A0A3G5UB86
# A0A8T9FAS1
# structure not found A0A8T9FAS1
# A0A7Z2STY0
# A0A1W5ZSE3
# A0A8T9T5Z7
# structure not found A0A8T9T5Z7
# A0A8T9RR54
# structure not found A0A8T9RR54
# A0A6P1HNY8
# A0A6P1HFR4
# A0A516KJT0
# A0A6I6UY47
# A0A221MEF8
# A0A220U740
# A0A075JST0
# A0A1B0T6A5
# structure not found A0A1B0T6A5
# H0UST6
# structure not found H0UST6
# A0A068ENZ6
# structure not found A0A068ENZ6
# A0A1B1P786
# structure not found A0A1B1P786
# A0A4P8N4T0
# structure not found A0A4P8N4T0
# A0A160FC76
# U5LFS4
# A0A6H3ACA0
# B7HT08
# B7JPI7
# Q73DP7
# B7IWX6
# B9J3W7
# C2W3Z4
# A7GL59
# A0A4P9F448
# A0A2B5NL02
# Q6HNL6
# A0A806HN73
# A0R9N5
# C2PA83
# A0A0M3RE22
# A0A0M4G834
# A0A0M4FPQ7
# A0A6F8TRF7
# A0A7Z2K7Z4
# A0A6B8KA71
# A0A8T9FFK4
# structure not found A0A8T9FFK4
# A0A8T9FFK4
# structure not found A0A8T9FFK4
# A0A8T9K338
# structure not found A0A8T9K338
# A0A7Z2SZN2
# A0A5P9HLI5
# A0A385NLJ8
# A0A2U8EEW0
# A0A160IIM1
# S5ZRX3
# S5ZRX3
# A0A679FHW6
# A0A0E0TEQ9
# A0A8U0AIC6
# structure not found A0A8U0AIC6
# A0A8U0ANS9
# structure not found A0A8U0ANS9
# I0JSP6
# A0A410MFJ3
# A0A410MES7
# A0A1W5ZRK0
# A0A8T9N5R9
# structure not found A0A8T9N5R9
# A0A8T9N342
# structure not found A0A8T9N342
# A0A0U4F518
# A0A7H8SAJ4
# B1HUT9
# A0A7S8CE02
# A0A7S8HGM5
# A0A3T0I385
# Q8EN90
# A0A345PE41
# A0A345PM60
# A0A8S0L6V7
# structure not found A0A8S0L6V7
# A0A6P1HH13
# A0A6H1PB23
# A0A5J6SU43
# A0A5J6PNV7
# A0A5S4Z6I7
# A0A6I6UTI9
# A0A6I6UPL9
# A0A6I6UR51
# A0A075LHN5
# A0A2K9IW55
# A0A2K9J471
# A0A2K9IZF0
# A0A2K9J047
# A0A2K9IXZ6
# A0A075JKC7
# A0A0B5AQA9
# A0A4P7A0I1
# A0A4P6ZW77
# A0A1C7DKM6
# A0A7H8QBB4
# A0A7Z2NN06
# A0A7G8XB40
# A0A7M2QTU0
# A0A1X9MGV7
# A0A1C3SD88
# A0A291KLC3
# A8FAH6
# A0A1L6ZHD0
# A0A8F8BDW7
# structure not found A0A8F8BDW7
# A0A5K1KSV2
# A0A0H3E2G4
# E0TY01
# A0A857HJ64
# A0A7U4KS82
# D4G1I3
# D4G1I3
# A0A7W4QCL5
# S6FLN1
# I2C3P4
# I2C4P6
# I2C5N7
# A0A807MCP9
# A0A6F8TS12
# A0A0X8KJX9
# E6TQP5
# O64094
# structure not found O64094
# P0DOE3
# structure not found P0DOE3
# A0A7G5CHT1
# structure not found A0A7G5CHT1
# A0A517IBE2
# A0A517IE81
# C0ZDG0
# C0Z4L6
# A0A291BT04
# A0A291BKT9
# A0A291BEY5
# A0A291BK34
# A0A220MMU8
# A0A220MFE2
# A0A220MGU1
# A0A518VED6
# A0A385T692
# A0A385T3E4
# A0A385T3E4
# A0A075RII6
# A0A075RII6
# A0A172ZAX4
# A0A2Z2KX58
# A0A2Z2KX58
# A0A0F7FGL9
# A0A6C0QM73
# structure not found A0A6C0QM73
# A0A2L1U980
# A0A6C0QU22
# structure not found A0A6C0QU22
# A0A1U9YLU3
# A0A1U9YPT3
# A0A1U9YPK5
# A0A3S8RZW0
# A0A7H0Y2E7
# A0A806PIQ5
# A0A1D7MQG5
# E0RHI2
# E0RKZ4
# G7VZS9
# G7VZH1
# A0A4Y6UY33
# S5MC02
# structure not found S5MC02
# A0A2Z4MR52
# C0ZJQ0
# A0A291BU46
# A0A7T5JMW1
# A0A7T5EIJ5
# A0A7T5EL03
# A0A7T5JNR9
# A0A220MQY1
# A0A518V4B4
# A0A518V314
# A0A385T3M4
# A0A518V1Q8
# A0A518V4D5
# A0A518V219
# A0A518V353
# A0A385T342
# A0A385T7V4
# A0A385T016
# A0A385TFQ4
# A0A385TII1
# A0A385T6Z3
# A0A518V1S1
# A0A075RBX2
# A0A075R5V6
# A0A075R862
# A0A075RAN3
# A0A075R5M8
# A0A075R1W4
# A0A075R1W4
# A0A075R6V5
# A0A075R948
# A0A075RCM7
# A0A075QYE8
# A0A075R6G0
# A0A075R207
# A0A383R821
# A0A383R4W7
# A0A0K2FLD1
# structure not found A0A0K2FLD1
# A0A0K2CNR6
# structure not found A0A0K2CNR6
# A0A3S6Z492
# C8WYH9
# A0A7T5ESM5
# A0A223D0Y3
# A0A1Y0IRA1
# A0A1L5LJS3
# Q97KG2
# W6RVV8
# B2TLA1
# D9SSU4
# A0A343JE52
# Q0ST04
# A0A1D7XHQ2
# Q898C9
# A0A3T0LSV0
# A0A2Z4WFR4
# A0A3G2R470
# U5S7M3
# F4BN04
# A0A6G7K9G3
# A0A3Q9BK89
# A0A6G7WHI8
# A0A133MT81
# A0A387B4I6
# A0A3S4NUA8
# A0A448D4L8
# A0A7G1IQM5
# F2QFT3
# F8DHW7
# A0A7H8V470
# A0A3R8S8M5
# A0A2I5KHZ4
# A0A2I5KRB1
# A0A2S2F733
# A0A2I5KI81
# G7SEP2
# A0A7G9AYC3
# A0A6G7Y1A2
# Q97M74
# Q97CZ5
# Q97TQ8
# A0A1W7LWQ5
# A0A410DXN0
# A0A3R5QR53
# A0A3R5UAV6
# A0A410DTG4
# A0A410DTG4
# A0A3R5QS52
# M1MZ65
# A0A7G9W5D9
# E8UV92
# D9TNF0
# A0A285BFV3
# A0A410QF08
# A0A6P1YE95
# Q9CDL4
# A0A4U9XQ67
# A0A448DD76
# Q5FMT7
# A0A226V1P2
# D5H0M3
# F0NX47
# A0A8G0ANX2
# structure not found A0A8G0ANX2
# A0A223CWZ9
# A0A223CYZ7
# A0A223CXX7
# A0A223CX87
# A0A223D1V7
# A0A223D340
# A0A1Y0IRN0
# A0A1Y0IPE1
# A0A1Y0II21
# A0A1Y0ISY6
# A0A1Y0IQZ0
# A0A1Y0IVU3
# A0A1Y0IRN0
# A0A1Y0IR72
# A0A1Y0IKA5
# A0A1Y0IJ68
# A0A1Y0IHR0
# A0A1Y0IWF6
# A0A1Y0IPD0
# A0A1Y0IQ51
# A0A1Y0IQ51
# A0A1Y0ILE5
# A0A1Y0IHU3
# A0A1Y0IPZ3
# A0A1Y0IMR9
# A0A1Y0IP73
# A0A2Z6BN59
# A0A5Q0EXQ8
# structure not found A0A5Q0EXQ8
# A0A7D4CEB2
# A0A7D3XNU7
# A0A7D3YA17
# A0A7D3XZ49
# A0A7D4BXG0
# A0A2I7SPI0
# A0A1U9K4D6
# A0A1U9K5B0
# A0A8D5UDA6
# structure not found A0A8D5UDA6
# A0A8D5ZQ46
# structure not found A0A8D5ZQ46
# A0A5Q0EQU7
# structure not found A0A5Q0EQU7
# A0A8S0N8Y1
# structure not found A0A8S0N8Y1
# Q7CC21
# C2YTQ0
# A0A7D4JKG1
# A0A3G4Z074
# Q5WJB6
# Q5WJ47
# Q5WD65
# A0A060M073
# A0A8D6L5F1
# structure not found A0A8D6L5F1
# M1MY12
# M1MWU1
# M1MYJ6
# M1MBP2
# G7M636
# G7M9E0
# G7M783
# A0A1B1L9H6
# W8CYT9
# structure not found W8CYT9
# A0A7T5EW61
# A0A220MJ59
# A0A223D573
# A0A223D190
# A0A1Y0IJN9
# A0A1Y0ILA0
# A0A1Y0IHI7
# A0A1Y0IM54
# A0A3Q9HRX4
# A0A3S9SZG5
# A0A3Q9HRH2
# A0A3S9SVK0
# A0A3Q9HPK8
# A0A6S6QSW8
# A0A6P1TLL5
# A9KPE5
# A0A223CYP7
# A0A1Y0IH37
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 16
#      13 with open(outfolder+'unmapped.txt', 'w') as simout:
#      14     simout.write(json.dumps(notfound))
# ---> 16 t, alnres = foldseek2tree.structblob2tree(outfolder + 'structs/',outfolder )
#
# File ~/UNILMNT/projects/snake_tree/notebooks/../src/foldseek2tree.py:223, in structblob2tree(input_folder, outfolder, overwrite, fastmepath, quicktreepath, foldseekpath, delta)
#     212 '''run structblob pipeline for a folder of pdb files without snakemake
#     213
#     214 Parameters
#    (...)
#     219 	path to output folder
#     220 '''
#     222 #check if the foldseek output is already there
# --> 223 if os.path.exists(outfolder + 'res.m8'):
#     224 	print('found foldseek output, skipping foldseek')
#     225 	alnres = outfolder + 'res.m8'
#
# NameError: name 'os' is not defined

# %%
t, alnres = foldseek2tree.structblob2tree(outfolder + 'structs/',outfolder , overwrite = True)
# Out:
# ../examples/rrnpp_final/res.m8 exists and will be overwritten
# easy-search ../examples/rrnpp_final/structs/ ../examples/rrnpp_final/structs/ ../examples/rrnpp_final/res.m8 tmp --format-output query,target,fident,alnlen,mismatch,gapopen,qstart,qend,tstart,tend,evalue,bits,lddt,lddtfull,alntmscore --exhaustive-search
#
# MMseqs Version:              	30fdcac78217579fa25d59bc271bd4f3767d3ebb
# Seq. id. threshold           	0
# Coverage threshold           	0
# Coverage mode                	0
# Max reject                   	2147483647
# Max accept                   	2147483647
# Add backtrace                	false
# TMscore threshold            	0
# TMalign hit order            	0
# TMalign fast                 	1
# Preload mode                 	0
# Threads                      	48
# Verbosity                    	3
# LDDT threshold               	0
# Sort by structure bit score  	1
# Substitution matrix          	aa:3di.out,nucl:3di.out
# Alignment mode               	3
# Alignment mode               	0
# E-value threshold            	10
# Min alignment length         	0
# Seq. id. mode                	0
# Alternative alignments       	0
# Max sequence length          	65535
# Compositional bias           	1
# Compositional bias           	1
# Gap open cost                	aa:10,nucl:10
# Gap extension cost           	aa:1,nucl:1
# Compressed                   	0
# Seed substitution matrix     	aa:3di.out,nucl:3di.out
# Sensitivity                  	9.5
# k-mer length                 	6
# k-score                      	seq:2147483647,prof:2147483647
# Max results per query        	1000
# Split database               	0
# Split mode                   	2
# Split memory limit           	0
# Diagonal scoring             	true
# Exact k-mer matching         	0
# Mask residues                	0
# Mask residues probability    	0.99995
# Mask lower case residues     	1
# Minimum diagonal score       	15
# Selected taxa
# Spaced k-mers                	1
# Spaced k-mer pattern
# Local temporary path
# Exhaustive search mode       	true
# Search iterations            	1
# Alignment type               	2
# Remove temporary files       	true
# MPI runner
# Force restart with latest tmp	false
# Chain name mode              	0
# Mask b-factor threshold      	0
# Coord store mode             	2
# Write lookup file            	1
# Tar Inclusion Regex          	.*
# Tar Exclusion Regex          	^$
# Alignment format             	0
# Format alignment output      	query,target,fident,alnlen,mismatch,gapopen,qstart,qend,tstart,tend,evalue,bits,lddt,lddtfull,alntmscore
# Database output              	false
#
# Alignment backtraces will be computed, since they were requested by output format.
# createdb ../examples/rrnpp_final/structs/ tmp/12879636901534954758/query --chain-name-mode 0 --mask-bfactor-threshold 0 --coord-store-mode 2 --write-lookup 1 --tar-include '.*' --tar-exclude '^$' --threads 48 -v 3
#
# Output file: tmp/12879636901534954758/query
# [=================================================================] 768 1s 965ms
# Time for merging to query_ss: 0h 0m 0s 42ms
# Time for merging to query_h: 0h 0m 0s 33ms
# Time for merging to query_ca: 0h 0m 0s 35ms
# Time for merging to query: 0h 0m 0s 34ms
# Ignore 0 out of 768.
# Too short: 0, incorrect  0.
# Time for processing: 0h 0m 2s 307ms
# createdb ../examples/rrnpp_final/structs/ tmp/12879636901534954758/target --chain-name-mode 0 --mask-bfactor-threshold 0 --coord-store-mode 2 --write-lookup 1 --tar-include '.*' --tar-exclude '^$' --threads 48 -v 3
#
# Output file: tmp/12879636901534954758/target
# [=================================================================] 768 1s 834ms
# Time for merging to target_ss: 0h 0m 0s 9ms
# Time for merging to target_h: 0h 0m 0s 8ms
# Time for merging to target_ca: 0h 0m 0s 9ms
# Time for merging to target: 0h 0m 0s 12ms
# Ignore 0 out of 768.
# Too short: 0, incorrect  0.
# Time for processing: 0h 0m 1s 934ms
# Create directory tmp/12879636901534954758/search_tmp
# search tmp/12879636901534954758/query tmp/12879636901534954758/target tmp/12879636901534954758/result tmp/12879636901534954758/search_tmp -a 1 --alignment-mode 3 --comp-bias-corr 1 --gap-open aa:10,nucl:10 --gap-extend aa:1,nucl:1 -s 9.5 -k 6 --mask 0 --mask-prob 0.99995 --exhaustive-search 1 --remove-tmp-files 1
#
# structurealign tmp/12879636901534954758/query tmp/12879636901534954758/target tmp/12879636901534954758/search_tmp/7660974535475304544/pref tmp/12879636901534954758/search_tmp/7660974535475304544/aln --tmscore-threshold 0 --lddt-threshold 0 --sort-by-structure-bits 1 --sub-mat 'aa:3di.out,nucl:3di.out' -a 1 --alignment-mode 3 --alignment-output-mode 0 --wrapped-scoring 0 -e 10 --min-seq-id 0 --min-aln-len 0 --seq-id-mode 0 --alt-ali 0 -c 0 --cov-mode 0 --max-seq-len 65535 --comp-bias-corr 1 --comp-bias-corr-scale 0.5 --max-rejected 2147483647 --max-accept 2147483647 --add-self-matches 0 --db-load-mode 0 --pca substitution:1.100,context:1.400 --pcb substitution:4.100,context:5.800 --score-bias 0 --realign 0 --realign-score-bias -0.2 --realign-max-seqs 2147483647 --corr-score-weight 0 --gap-open aa:10,nucl:10 --gap-extend aa:1,nucl:1 --zdrop 40 --threads 48 --compressed 0 -v 3
#
# [=================================================================] 768 15m 17s 683ms
# Time for merging to aln: 0h 0m 0s 121ms
# Time for processing: 0h 15m 50s 676ms
# mvdb tmp/12879636901534954758/search_tmp/7660974535475304544/aln tmp/12879636901534954758/result -v 3
#
# Time for processing: 0h 0m 0s 91ms
# Removing temporary files
# rmdb tmp/12879636901534954758/search_tmp/7660974535475304544/pref -v 3
#
# Time for processing: 0h 0m 0s 7ms
# ../examples/rrnpp_final/res.m8 exists and will be overwritten
# convertalis tmp/12879636901534954758/query tmp/12879636901534954758/target tmp/12879636901534954758/result ../examples/rrnpp_final/res.m8 --sub-mat 'aa:3di.out,nucl:3di.out' --format-mode 0 --format-output query,target,fident,alnlen,mismatch,gapopen,qstart,qend,tstart,tend,evalue,bits,lddt,lddtfull,alntmscore --translation-table 1 --gap-open aa:10,nucl:10 --gap-extend aa:1,nucl:1 --db-output 0 --db-load-mode 0 --search-type 0 --threads 48 --compressed 0 -v 3
#
# [=================================================================] 768 10m 52s 195ms
# Time for merging to res.m8: 0h 0m 4s 573ms
# Time for processing: 0h 11m 0s 920ms
# rmdb tmp/12879636901534954758/result -v 3
#
# Time for processing: 0h 0m 0s 9ms
# rmdb tmp/12879636901534954758/target -v 3
#
# Time for processing: 0h 0m 0s 7ms
# rmdb tmp/12879636901534954758/target_h -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/12879636901534954758/target_ca -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/12879636901534954758/target_ss -v 3
#
# Time for processing: 0h 0m 0s 3ms
# rmdb tmp/12879636901534954758/query -v 3
#
# Time for processing: 0h 0m 0s 1ms
# rmdb tmp/12879636901534954758/query_h -v 3
#
# Time for processing: 0h 0m 0s 0ms
# rmdb tmp/12879636901534954758/query_ca -v 3
#
# Time for processing: 0h 0m 0s 2ms
# rmdb tmp/12879636901534954758/query_ss -v 3
#
# Time for processing: 0h 0m 0s 10ms
#              query      target  fident  alnlen  mismatch  gapopen  qstart  \
# 0       A0A6M8D843  A0A6M8D843   1.000     383         0        0       1
# 1       A0A6M8D843  A0A0K0QCL2   0.906     383        36        0       1
# 2       A0A6M8D843      B7IY66   0.932     383        26        0       1
# 3       A0A6M8D843      K0FM26   0.788     383        81        0       1
# 4       A0A6M8D843  A0A5C1FEK2   0.785     383        82        0       1
# ...            ...         ...     ...     ...       ...      ...     ...
# 589679  A0A3Q9HPK8  A0A7H8V064   0.108     250       167       12       1
# 589680  A0A3Q9HPK8  A0A0X8GYF8   0.112     257       180       11      59
# 589681  A0A3Q9HPK8  A0A0Z8EDW7   0.108     250       167       11       1
# 589682  A0A3Q9HPK8  A0A2X3SEZ5   0.115     268       172       13      28
# 589683  A0A3Q9HPK8      K8E6J0   0.097     287       198       13      30
#
#         qend  tstart  tend        evalue  bits    lddt  \
# 0        383       1   383  1.036000e-48  2815  1.0000
# 1        383       1   383  2.636000e-45  2600  0.9858
# 2        383       1   383  5.259000e-45  2570  0.9803
# 3        383       1   383  2.119000e-40  2307  0.9756
# 4        383       1   383  1.301000e-40  2277  0.9474
# ...      ...     ...   ...           ...   ...     ...
# 589679   228      70   285  1.035000e+00    38  0.4398
# 589680   291      30   262  7.620000e-01    36  0.3788
# 589681   228      70   285  1.346000e+00    35  0.4250
# 589682   278      64   283  5.861000e-01    34  0.3959
# 589683   297      61   305  8.689000e-01    33  0.3916
#
#                                                  lddtfull  alntmscore
# 0       1.000,1.000,1.000,1.000,1.000,1.000,1.000,1.00...      1.0000
# 1       0.875,0.914,0.898,0.913,0.944,0.946,0.944,0.96...      0.9980
# 2       1.000,1.000,0.930,0.948,0.968,0.970,0.939,0.96...      0.9936
# 3       0.941,0.993,0.961,0.983,1.000,0.988,0.989,1.00...      0.9930
# 4       0.809,0.871,0.742,0.738,0.838,0.857,0.794,0.83...      0.9861
# ...                                                   ...         ...
# 589679  0.147,0.200,0.339,0.382,0.375,0.478,0.505,0.42...      0.4407
# 589680  0.229,0.276,0.282,0.223,0.224,0.240,0.292,0.27...      0.3826
# 589681  0.147,0.240,0.411,0.375,0.375,0.434,0.462,0.38...      0.4342
# 589682  0.155,0.197,0.199,0.186,0.257,0.300,0.237,0.36...      0.2983
# 589683  0.168,0.147,0.230,0.250,0.178,0.358,0.413,0.30...      0.3294
#
# [589684 rows x 15 columns]
# [[0.     0.8415 0.869  ... 0.826  0.8735 0.838 ]
#  [0.8415 0.     0.8775 ... 0.825  0.8585 0.85  ]
#  [0.869  0.8775 0.     ... 0.862  0.7995 0.8505]
#  ...
#  [0.826  0.825  0.862  ... 0.     0.878  0.8245]
#  [0.8735 0.8585 0.7995 ... 0.878  0.     0.855 ]
#  [0.838  0.85   0.8505 ... 0.8245 0.855  0.    ]] 1.0 0.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 t, alnres = foldseek2tree.structblob2tree(outfolder + 'structs/',outfolder , overwrite = True)
#
# File /work/FAC/FBM/DBC/cdessim2/default/dmoi/projects/snake_tree/notebooks/../src/foldseek2tree.py:250, in structblob2tree(input_folder, outfolder, overwrite, fastmepath, quicktreepath, foldseekpath, delta)
#     248 	matrices[k] = 1-matrices[k]
#     249 	print(matrices[k], np.amax(matrices[k]), np.amin(matrices[k]) )
# --> 250 	np.save( infolder + k + '_distmat.npy' , matrices[k])
#     251 	distmat_txt = foldseek2tree.distmat_to_txt( ids , matrices[k] , snakemake.output[i] )
#     253 distmat_txt = distmat_to_txt( ids , distmat , input_folder + 'fastme_mat.txt'  )
#
# NameError: name 'infolder' is not defined

# %%
#cut the structures down to their cores
import corecut
core = corecut.extract_core(outfolder + 'res.m8' , outfile = outfolder+'core.csv',  hitthresh = .75 ,minthresh = .25, corefolder = 'core_structs/' , structfolder = 'structs/' )
# Out:
# ../examples/rrnpp_final/
# extracting core
# hitthresh: 0.75
# minthresh: 0.25
#             query          target  fident  alnlen  mismatch  gapopen  qstart  \
# 0  A0A6M8D843.pdb  A0A6M8D843.pdb   1.000     383         0        0       1
# 1  A0A6M8D843.pdb  A0A0K0QCL2.pdb   0.906     383        36        0       1
# 2  A0A6M8D843.pdb      B7IY66.pdb   0.932     383        26        0       1
# 3  A0A6M8D843.pdb      K0FM26.pdb   0.788     383        81        0       1
# 4  A0A6M8D843.pdb  A0A5C1FEK2.pdb   0.785     383        82        0       1
#
#    qend  tstart  tend        evalue  bits    lddt  \
# 0   383       1   383  1.036000e-48  2815  1.0000
# 1   383       1   383  2.636000e-45  2600  0.9858
# 2   383       1   383  5.259000e-45  2570  0.9803
# 3   383       1   383  2.119000e-40  2307  0.9756
# 4   383       1   383  1.301000e-40  2277  0.9474
#
#                                             lddtfull  alntmscore
# 0  1.000,1.000,1.000,1.000,1.000,1.000,1.000,1.00...      1.0000
# 1  0.875,0.914,0.898,0.913,0.944,0.946,0.944,0.96...      0.9980
# 2  1.000,1.000,0.930,0.948,0.968,0.970,0.939,0.96...      0.9936
# 3  0.941,0.993,0.961,0.983,1.000,0.988,0.989,1.00...      0.9930
# 4  0.809,0.871,0.742,0.738,0.838,0.857,0.794,0.83...      0.9861   768
# processed: 575:  75%|███████▍  | 574/768 [00:39<00:13, 14.72it/s]

# %%
#make a directory for the core results
try:
    os.mkdir(outfolder +'core_res/')
except:
    print('already exists')
t, alnres = foldseek2tree.structblob2tree(outfolder + 'core_structs/',outfolder + 'core_res/' )

# %%
#
