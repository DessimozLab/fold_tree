# %%
# %load_ext autoreload
# %autoreload 2

import seaborn as sns
import glob
import os
import numpy as np
import sys
sys.path.append( '../src/')
from matplotlib import pyplot as plt
from compile_treeset import compile_folder , compare_treesets

# %%
import pandas as pd
import plotly.express as px
import plotly.figure_factory as ff

def graph_treedf(tree_resdf , rescols, rescols_norm , outfolder = '../figures/' , prefix = '' ):
    #sns.violinplot(tree_resdf[rescols] , hue=tree_resdf.filtered, split=True , cut =0 , bw=.15)
    if os.path.exists(outfolder ) == False:
        os.mkdir(outfolder)
    
    
    sns.set(rc={'figure.figsize':(10,8)})
    graph = sns.violinplot(tree_resdf[rescols] , cut = 0 , inner= 'box' )
    graph.axhline(max([tree_resdf[col].median() for col in rescols ]) , dashes = [2 , 1 ] )
    plt.xticks(rotation=45)
    
    
    plt.show()
    plt.savefig( outfolder + prefix + '_score.svg')

    sns.set(rc={'figure.figsize':(10,8)})
    graph = sns.violinplot(tree_resdf[rescols_norm] , cut = 0    )
    graph.axhline(max([tree_resdf[col].median() for col in rescols_norm ]) , dashes = [2 , 1 ] )
    plt.xticks(rotation=45)
    plt.show()
    
    
    plt.savefig( outfolder + prefix + '_norm_score.svg')
    
    clean = tree_resdf[rescols].dropna()
    fig = ff.create_distplot([ clean[col] for col in rescols ], [col for col in rescols] , bin_size = 150, show_rug = True)
    fig.show()
    
    



#cladefolders = ['../CATH_data/' , '../CAT_data/' , '../SCOP_data/' ]
#todo iterate over hogs and cath and train a model

cladefolders = set(glob.glob( '../OMA_data/*/' ))-set([ '../OMA_data/logs/' ])

cladefolders = cladefolders.union( set(glob.glob( '../OMA_data_unfiltered/OMA_data/*/' )) - set([ '../OMA_data_unfiltered/logs/' ]) )

#cladefolders = set(glob.glob( '../OMA_data/*/' ))-set([ '../OMA_data/logs/' ])

#cladefolders= set([])
#cladefolders = cladefolders.union( set( [ '../CATH_data/'   ] ) )

scorefunc = 'score'
rescols = ['lddt_1_raw_struct_tree' , 'fident_1_raw_struct_tree', 'alntmscore_1_raw_struct_tree', 'sequences' ]
rescols_norm = ['lddt_1_raw_struct_tree'+'_norm' , 'fident_1_raw_struct_tree'+'_norm', 'alntmscore_1_raw_struct_tree'+'_norm' , 'sequences'+'_norm']
dfs = []
plotall = False

for folder in cladefolders:
    #try:
    if 'logs' not in folder:
        print(folder)
        res = compile_folder(folder, scorefunc = scorefunc, verbose = False)
        if res :
            tree_resdf , refcols = res
            compare_treesets(tree_resdf  , colfilter= 'sequence' , display_lineplot = False , verbose = True)
            tree_resdf['folder'] = folder

            #add filtered bool column
            tree_resdf['filtered'] = tree_resdf['folder'].apply(lambda x : 'unfiltered' in x)
            
            if 'OMA' in folder:
                dfs.append(tree_resdf)
                if plotall == True:
                    graph_treedf(tree_resdf , rescols, rescols_norm)
            else:
                graph_treedf(tree_resdf , rescols, rescols_norm)

            
total_df = pd.concat(dfs)
graph_treedf(total_df[total_df.filtered == False] , rescols, rescols_norm , prefix = 'OMA' )
graph_treedf(total_df[total_df.filtered == True] , rescols, rescols_norm , prefix = 'OMA' )


            #except:
        #    print('failed', folder)
# Out:
# ../OMA_data/Bilateria/
# ../OMA_data/Bilateria/
# 558
# processed: 551:   8%|▊         | 44/558 [00:00<00:01, 424.86it/s]
# nseqs != nstructs ../OMA_data/Bilateria/HOG3/
# 3 30
# nseqs != nstructs ../OMA_data/Bilateria/HOG1022/
# 7 11
# nseqs != nstructs ../OMA_data/Bilateria/HOG921/
# 19 20
# nseqs != nstructs ../OMA_data/Bilateria/HOG448/
# 11 22
# nseqs != nstructs ../OMA_data/Bilateria/HOG156/
# 12 29
# nseqs != nstructs ../OMA_data/Bilateria/HOG991/
# 8 31
# nseqs != nstructs ../OMA_data/Bilateria/HOG127/
# 6 19
# nseqs != nstructs ../OMA_data/Bilateria/HOG939/
# 4 15
# nseqs != nstructs ../OMA_data/Bilateria/HOG984/
# 5 12
# nseqs != nstructs ../OMA_data/Bilateria/HOG303/
# 4 18
# nseqs != nstructs ../OMA_data/Bilateria/HOG340/
# 23 28
# nseqs != nstructs ../OMA_data/Bilateria/HOG204/
# 15 29
# nseqs != nstructs ../OMA_data/Bilateria/HOG371/
# 19 25
# nseqs != nstructs ../OMA_data/Bilateria/HOG298/
# 31 48
# nseqs != nstructs ../OMA_data/Bilateria/HOG667/
# 3 32
# nseqs != nstructs ../OMA_data/Bilateria/HOG843/
# 6 23
# nseqs != nstructs ../OMA_data/Bilateria/HOG56/
# 11 14
# nseqs != nstructs ../OMA_data/Bilateria/HOG40/
# 8 14
# nseqs != nstructs ../OMA_data/Bilateria/HOG962/
# 12 13
# nseqs != nstructs ../OMA_data/Bilateria/HOG728/
# 5 15
# nseqs != nstructs ../OMA_data/Bilateria/HOG541/
# 13 15
# nseqs != nstructs ../OMA_data/Bilateria/HOG394/
# 3 12
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/miniconda3/envs/ML2/lib/python3.10/site-packages/scipy/stats/_morestats.py:3337: UserWarning:
#
# Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
# lddt_1_raw_struct_tree sequences
# delta: 1786.0 delta norm: 3.1321286758701694 WilcoxonResult(statistic=78.0, pvalue=0.7439202218465143)
# fident_1_raw_struct_tree sequences
# delta: 2765.0 delta norm: 5.272903903104326 WilcoxonResult(statistic=18.0, pvalue=0.01696959812866174)
# alntmscore_1_raw_struct_tree sequences
# delta: 1204.0 delta norm: 2.4535237692784415 WilcoxonResult(statistic=81.0, pvalue=0.8446102947853842)
# lddt_0_raw_struct_tree sequences
# delta: 1805.0 delta norm: 3.3031216427468584 WilcoxonResult(statistic=85.0, pvalue=0.6873436403522856)
# fident_0_raw_struct_tree sequences
# delta: 1793.0 delta norm: 2.650087007112011 WilcoxonResult(statistic=98.0, pvalue=0.7938214901244397)
# alntmscore_0_raw_struct_tree sequences
# delta: 1100.0 delta norm: 1.9426937922726748 WilcoxonResult(statistic=93.0, pvalue=0.9358520318812181)
# ../OMA_data_unfiltered/OMA_data/Bacteria/
# ../OMA_data_unfiltered/OMA_data/Bacteria/
# 117
# processed: 117: 100%|██████████| 117/117 [00:00<00:00, 571.81it/s]
# lddt_1_raw_struct_tree sequences
# delta: -234.0 delta norm: -2.9293897658413606 WilcoxonResult(statistic=1234.0, pvalue=0.005980573103812576)
# fident_1_raw_struct_tree sequences
# delta: 98 delta norm: 0.0937294414736526 WilcoxonResult(statistic=1761.0, pvalue=0.7698322060295003)
# alntmscore_1_raw_struct_tree sequences
# delta: -758 delta norm: -7.742521614933133 WilcoxonResult(statistic=919.0, pvalue=1.452167991698958e-09)
# lddt_0_raw_struct_tree sequences
# delta: -244 delta norm: -2.608867440891618 WilcoxonResult(statistic=1249.0, pvalue=0.0019986990693325523)
# fident_0_raw_struct_tree sequences
# delta: -357 delta norm: -4.144244701108318 WilcoxonResult(statistic=995.5, pvalue=6.0532412662320604e-05)
# alntmscore_0_raw_struct_tree sequences
# delta: -766 delta norm: -8.15575985401108 WilcoxonResult(statistic=918.5, pvalue=1.1437113625726341e-08)
# ../OMA_data/Eumetazoa/
# ../OMA_data/Eumetazoa/
# 896
# processed: 895:   7%|▋         | 63/896 [00:00<00:01, 529.20it/s]
# nseqs != nstructs ../OMA_data/Eumetazoa/HOG1421/
# 13 24
# nseqs != nstructs ../OMA_data/Eumetazoa/HOG347/
# 4 34
# nseqs != nstructs ../OMA_data/Eumetazoa/HOG767/
# 6 35
# nseqs != nstructs ../OMA_data/Eumetazoa/HOG180/
# 79 88
# nseqs != nstructs ../OMA_data/Eumetazoa/HOG1469/
# 11 13
# nseqs != nstructs ../OMA_data/Eumetazoa/HOG877/
# 12 16
# nseqs != nstructs ../OMA_data/Eumetazoa/HOG714/
# 13 15
# nseqs != nstructs ../OMA_data/Eumetazoa/HOG255/
# 4 27
# nseqs != nstructs ../OMA_data/Eumetazoa/HOG631/
# 4 20
# nseqs != nstructs ../OMA_data/Eumetazoa/HOG653/
# 4 25
# nseqs != nstructs ../OMA_data/Eumetazoa/HOG368/
# 99 111
# nseqs != nstructs ../OMA_data/Eumetazoa/HOG521/
# 20 22
# nseqs != nstructs ../OMA_data/Eumetazoa/HOG1041/
# 6 16
# nseqs != nstructs ../OMA_data/Eumetazoa/HOG65/
# 57 58
# nseqs != nstructs ../OMA_data/Eumetazoa/HOG374/
# 56 100
# nseqs != nstructs ../OMA_data/Eumetazoa/HOG50/
# 22 26
# nseqs != nstructs ../OMA_data/Eumetazoa/HOG1420/
# 4 11
# nseqs != nstructs ../OMA_data/Eumetazoa/HOG1116/
# 13 16
# nseqs != nstructs ../OMA_data/Eumetazoa/HOG998/
# 17 18
# nseqs != nstructs ../OMA_data/Eumetazoa/HOG497/
# 9 13
# nseqs != nstructs ../OMA_data/Eumetazoa/HOG197/
# 13 18
# nseqs != nstructs ../OMA_data/Eumetazoa/HOG553/
# 5 18
# nseqs != nstructs ../OMA_data/Eumetazoa/HOG1451/
# 12 27
# nseqs != nstructs ../OMA_data/Eumetazoa/HOG562/
# 17 33
# nseqs != nstructs ../OMA_data/Eumetazoa/HOG870/
# 48 74
# lddt_1_raw_struct_tree sequences
# delta: 1006.0 delta norm: 1.0758792002690933 WilcoxonResult(statistic=177.5, pvalue=0.38696726384328684)
# fident_1_raw_struct_tree sequences
# delta: 1965.0 delta norm: 4.2958946509647244 WilcoxonResult(statistic=92.5, pvalue=0.020376989766076156)
# alntmscore_1_raw_struct_tree sequences
# delta: 56.0 delta norm: -0.6837119516036614 WilcoxonResult(statistic=138.5, pvalue=0.1418729310648753)
# lddt_0_raw_struct_tree sequences
# delta: 856.0 delta norm: 0.28629603962101163 WilcoxonResult(statistic=140.5, pvalue=0.3739833359372938)
# fident_0_raw_struct_tree sequences
# delta: 919.0 delta norm: 0.44644012522118526 WilcoxonResult(statistic=167.5, pvalue=0.41882344258739235)
# alntmscore_0_raw_struct_tree sequences
# delta: -140.0 delta norm: -1.2613534215007027 WilcoxonResult(statistic=135.0, pvalue=0.12151235710849262)
# ../OMA_data_unfiltered/OMA_data/Eumetazoa/
# ../OMA_data_unfiltered/OMA_data/Eumetazoa/
# 117
# processed: 117:  96%|█████████▌| 112/117 [00:00<00:00, 579.11it/s]
# lddt_1_raw_struct_tree sequences
# delta: -4667 delta norm: -12.61217188967509 WilcoxonResult(statistic=26.5, pvalue=3.889426124253735e-19)
# fident_1_raw_struct_tree sequences
# delta: -482 delta norm: -1.4614164998610375 WilcoxonResult(statistic=1439.5, pvalue=7.321260610805279e-05)
# alntmscore_1_raw_struct_tree sequences
# delta: -9945 delta norm: -26.60925148743963 WilcoxonResult(statistic=0.0, pvalue=5.968218446086339e-20)
# lddt_0_raw_struct_tree sequences
# delta: -4996 delta norm: -13.886659768759012 WilcoxonResult(statistic=45.5, pvalue=6.581032788277233e-19)
# fident_0_raw_struct_tree sequences
# delta: -4988 delta norm: -14.445807933235596 WilcoxonResult(statistic=24.5, pvalue=3.6866392826687744e-19)
# alntmscore_0_raw_struct_tree sequences
# delta: -10066 delta norm: -27.21390665388011 WilcoxonResult(statistic=0.0, pvalue=5.976147084278544e-20)
# ../OMA_data_unfiltered/OMA_data/Eukaryota/
# ../OMA_data_unfiltered/OMA_data/Eukaryota/
# 117
# processed: 117:  98%|█████████▊| 115/117 [00:00<00:00, 568.99it/s]
# lddt_1_raw_struct_tree sequences
# delta: -10453 delta norm: -18.105876220111693 WilcoxonResult(statistic=14.5, pvalue=2.79621733172368e-19)
# fident_1_raw_struct_tree sequences
# delta: -1744 delta norm: -2.3673738607027364 WilcoxonResult(statistic=957.5, pvalue=1.9141444361958713e-09)
# alntmscore_1_raw_struct_tree sequences
# delta: -20448 delta norm: -37.67331156397845 WilcoxonResult(statistic=1.5, pvalue=2.9149237197596926e-20)
# lddt_0_raw_struct_tree sequences
# delta: -10282 delta norm: -18.572240607639927 WilcoxonResult(statistic=21.0, pvalue=1.551523173939683e-19)
# fident_0_raw_struct_tree sequences
# delta: -10332 delta norm: -19.031652198553925 WilcoxonResult(statistic=12.5, pvalue=1.230593261192895e-19)
# alntmscore_0_raw_struct_tree sequences
# delta: -20796 delta norm: -37.76152582105307 WilcoxonResult(statistic=0.0, pvalue=4.0937803523586947e-20)
# ../OMA_data/Dikarya/
# ../OMA_data/Dikarya/
# 186
# processed: 185:  22%|██▏       | 41/186 [00:00<00:00, 618.01it/s]
# nseqs != nstructs ../OMA_data/Dikarya/HOG16/
# 5 11
# nseqs != nstructs ../OMA_data/Dikarya/HOG38/
# 4 12
# nseqs != nstructs ../OMA_data/Dikarya/HOG134/
# 4 19
# nseqs != nstructs ../OMA_data/Dikarya/HOG42/
# 10 11
# nseqs != nstructs ../OMA_data/Dikarya/HOG155/
# 3 11
# nseqs != nstructs ../OMA_data/Dikarya/HOG64/
# 8 11
# nseqs != nstructs ../OMA_data/Dikarya/HOG154/
# 5 21
# nseqs != nstructs ../OMA_data/Dikarya/HOG4/
# 9 13
# nseqs != nstructs ../OMA_data/Dikarya/HOG0/
# 4 41
# nseqs != nstructs ../OMA_data/Dikarya/HOG166/
# 3 12
# nseqs != nstructs ../OMA_data/Dikarya/HOG144/
# 4 11
# nseqs != nstructs ../OMA_data/Dikarya/HOG76/
# 6 13
# nseqs != nstructs ../OMA_data/Dikarya/HOG161/
# 7 12
# nseqs != nstructs ../OMA_data/Dikarya/HOG114/
# 14 22
# nseqs != nstructs ../OMA_data/Dikarya/HOG8/
# 9 11
# nseqs != nstructs ../OMA_data/Dikarya/HOG146/
# 11 12
# nseqs != nstructs ../OMA_data/Dikarya/HOG47/
# 6 11
# nseqs != nstructs ../OMA_data/Dikarya/HOG46/
# 6 11
# nseqs != nstructs ../OMA_data/Dikarya/HOG57/
# 8 11
# nseqs != nstructs ../OMA_data/Dikarya/HOG152/
# 9 13
# nseqs != nstructs ../OMA_data/Dikarya/HOG116/
# 4 15
# nseqs != nstructs ../OMA_data/Dikarya/HOG32/
# 4 11
# nseqs != nstructs ../OMA_data/Dikarya/HOG73/
# 10 12
# nseqs != nstructs ../OMA_data/Dikarya/HOG147/
# 12 13
# nseqs != nstructs ../OMA_data/Dikarya/HOG9/
# 6 46
# nseqs != nstructs ../OMA_data/Dikarya/HOG27/
# 7 11
# nseqs != nstructs ../OMA_data/Dikarya/HOG15/
# 16 18
# lddt_1_raw_struct_tree sequences
# delta: 457 delta norm: 2.3714222186784943 WilcoxonResult(statistic=15.0, pvalue=0.10916025906553788)
# fident_1_raw_struct_tree sequences
# delta: 486 delta norm: 2.762741366035583 WilcoxonResult(statistic=2.0, pvalue=0.009161227493386)
# alntmscore_1_raw_struct_tree sequences
# delta: 278 delta norm: 1.4688969898620108 WilcoxonResult(statistic=38.0, pvalue=0.9374489089506656)
# lddt_0_raw_struct_tree sequences
# delta: 393 delta norm: 1.3272595191487155 WilcoxonResult(statistic=30.5, pvalue=0.504410939972533)
# fident_0_raw_struct_tree sequences
# delta: 350 delta norm: 1.2691350212503407 WilcoxonResult(statistic=26.0, pvalue=0.8784817434328712)
# alntmscore_0_raw_struct_tree sequences
# delta: 274 delta norm: 0.5847060878680321 WilcoxonResult(statistic=32.0, pvalue=0.5827745415043184)
# ../OMA_data/Bacteria/
# ../OMA_data/Bacteria/
# 633
# processed: 628:  15%|█▍        | 93/633 [00:00<00:00, 574.22it/s]
# nseqs != nstructs ../OMA_data/Bacteria/HOG56/
# 11 14
# nseqs != nstructs ../OMA_data/Bacteria/HOG206/
# 35 57
# nseqs != nstructs ../OMA_data/Bacteria/HOG216/
# 24 25
# nseqs != nstructs ../OMA_data/Bacteria/HOG79/
# 4 11
# nseqs != nstructs ../OMA_data/Bacteria/HOG283/
# 3 21
# nseqs != nstructs ../OMA_data/Bacteria/HOG418/
# 15 17
# nseqs != nstructs ../OMA_data/Bacteria/HOG153/
# 22 28
# nseqs != nstructs ../OMA_data/Bacteria/HOG142/
# 93 100
# nseqs != nstructs ../OMA_data/Bacteria/HOG361/
# 31 32
# nseqs != nstructs ../OMA_data/Bacteria/HOG117/
# 15 24
# nseqs != nstructs ../OMA_data/Bacteria/HOG538/
# 5 15
# nseqs != nstructs ../OMA_data/Bacteria/HOG105/
# 20 21
# nseqs != nstructs ../OMA_data/Bacteria/HOG612/
# 11 13
# nseqs != nstructs ../OMA_data/Bacteria/HOG414/
# 8 13
# nseqs != nstructs ../OMA_data/Bacteria/HOG253/
# 153 157
# nseqs != nstructs ../OMA_data/Bacteria/HOG158/
# 20 22
# nseqs != nstructs ../OMA_data/Bacteria/HOG353/
# 15 21
# nseqs != nstructs ../OMA_data/Bacteria/HOG57/
# 16 21
# nseqs != nstructs ../OMA_data/Bacteria/HOG120/
# 30 31
# nseqs != nstructs ../OMA_data/Bacteria/HOG88/
# 10 12
# nseqs != nstructs ../OMA_data/Bacteria/HOG148/
# 79 96
# nseqs != nstructs ../OMA_data/Bacteria/HOG93/
# 16 21
# nseqs != nstructs ../OMA_data/Bacteria/HOG161/
# 17 19
# nseqs != nstructs ../OMA_data/Bacteria/HOG215/
# 29 69
# nseqs != nstructs ../OMA_data/Bacteria/HOG134/
# 89 124
# nseqs != nstructs ../OMA_data/Bacteria/HOG71/
# 12 13
# nseqs != nstructs ../OMA_data/Bacteria/HOG83/
# 15 16
# nseqs != nstructs ../OMA_data/Bacteria/HOG637/
# 24 27
# nseqs != nstructs ../OMA_data/Bacteria/HOG279/
# 18 20
# nseqs != nstructs ../OMA_data/Bacteria/HOG32/
# 23 25
# nseqs != nstructs ../OMA_data/Bacteria/HOG67/
# 4 13
# nseqs != nstructs ../OMA_data/Bacteria/HOG133/
# 16 20
# nseqs != nstructs ../OMA_data/Bacteria/HOG591/
# 12 15
# nseqs != nstructs ../OMA_data/Bacteria/HOG27/
# 14 20
# nseqs != nstructs ../OMA_data/Bacteria/HOG205/
# 21 23
# nseqs != nstructs ../OMA_data/Bacteria/HOG119/
# 17 20
# nseqs != nstructs ../OMA_data/Bacteria/HOG646/
# 13 15
# nseqs != nstructs ../OMA_data/Bacteria/HOG572/
# 6 10
# nseqs != nstructs ../OMA_data/Bacteria/HOG527/
# 10 16
# nseqs != nstructs ../OMA_data/Bacteria/HOG310/
# 30 38
# nseqs != nstructs ../OMA_data/Bacteria/HOG37/
# 25 26
# nseqs != nstructs ../OMA_data/Bacteria/HOG564/
# 17 20
# lddt_1_raw_struct_tree sequences
# delta: 253.0 delta norm: 1.787044550120331 WilcoxonResult(statistic=210.0, pvalue=0.2068029555613079)
# fident_1_raw_struct_tree sequences
# delta: 344.0 delta norm: 2.5576771848547883 WilcoxonResult(statistic=80.5, pvalue=0.002986208126078565)
# alntmscore_1_raw_struct_tree sequences
# delta: -13.0 delta norm: -0.7089465227026144 WilcoxonResult(statistic=264.5, pvalue=0.12369484348664457)
# lddt_0_raw_struct_tree sequences
# delta: 238.0 delta norm: 1.5750762078884286 WilcoxonResult(statistic=240.5, pvalue=0.4735302809253713)
# fident_0_raw_struct_tree sequences
# delta: 168.0 delta norm: 0.6261857695842754 WilcoxonResult(statistic=334.5, pvalue=0.7968625836772709)
# alntmscore_0_raw_struct_tree sequences
# delta: 64.0 delta norm: 0.14991426252967935 WilcoxonResult(statistic=319.0, pvalue=0.4541513182083611)
# ../OMA_data_unfiltered/OMA_data/Bilateria/
# ../OMA_data_unfiltered/OMA_data/Bilateria/
# 117
# processed: 117: 100%|██████████| 117/117 [00:00<00:00, 584.21it/s]
# lddt_1_raw_struct_tree sequences
# delta: -4402 delta norm: -12.753373436814071 WilcoxonResult(statistic=66.5, pvalue=7.884582975345887e-19)
# fident_1_raw_struct_tree sequences
# delta: -435 delta norm: -0.8653198781122236 WilcoxonResult(statistic=1376.0, pvalue=0.00012319006679876058)
# alntmscore_1_raw_struct_tree sequences
# delta: -8371 delta norm: -25.7912373639566 WilcoxonResult(statistic=9.0, pvalue=1.6562728792202854e-20)
# lddt_0_raw_struct_tree sequences
# delta: -4602 delta norm: -13.680723241644186 WilcoxonResult(statistic=73.0, pvalue=2.8602928585747724e-19)
# fident_0_raw_struct_tree sequences
# delta: -4660 delta norm: -14.046958992781574 WilcoxonResult(statistic=44.5, pvalue=2.933041204245716e-19)
# alntmscore_0_raw_struct_tree sequences
# delta: -8905 delta norm: -27.25317067537487 WilcoxonResult(statistic=15.5, pvalue=1.9666988172953297e-20)
# ../OMA_data/LUCA/
# ../OMA_data/LUCA/
# 880
# processed: 872:  12%|█▎        | 110/880 [00:00<00:01, 585.89it/s]
# nseqs != nstructs ../OMA_data/LUCA/HOG1077/
# 36 59
# nseqs != nstructs ../OMA_data/LUCA/HOG1061/
# 16 21
# nseqs != nstructs ../OMA_data/LUCA/HOG1351/
# 8 12
# nseqs != nstructs ../OMA_data/LUCA/HOG1173/
# 4 74
# nseqs != nstructs ../OMA_data/LUCA/HOG885/
# 24 33
# nseqs != nstructs ../OMA_data/LUCA/HOG1104/
# 11 22
# nseqs != nstructs ../OMA_data/LUCA/HOG1171/
# 12 45
# nseqs != nstructs ../OMA_data/LUCA/HOG954/
# 28 29
# nseqs != nstructs ../OMA_data/LUCA/HOG930/
# 18 22
# nseqs != nstructs ../OMA_data/LUCA/HOG734/
# 28 37
# nseqs != nstructs ../OMA_data/LUCA/HOG1292/
# 32 37
# nseqs != nstructs ../OMA_data/LUCA/HOG144/
# 59 112
# nseqs != nstructs ../OMA_data/LUCA/HOG1311/
# 11 22
# nseqs != nstructs ../OMA_data/LUCA/HOG657/
# 78 82
# nseqs != nstructs ../OMA_data/LUCA/HOG883/
# 10 30
# nseqs != nstructs ../OMA_data/LUCA/HOG1014/
# 9 35
# nseqs != nstructs ../OMA_data/LUCA/HOG282/
# 58 67
# nseqs != nstructs ../OMA_data/LUCA/HOG1301/
# 9 59
# nseqs != nstructs ../OMA_data/LUCA/HOG752/
# 14 37
# nseqs != nstructs ../OMA_data/LUCA/HOG80/
# 38 65
# nseqs != nstructs ../OMA_data/LUCA/HOG1249/
# 7 11
# nseqs != nstructs ../OMA_data/LUCA/HOG383/
# 31 50
# nseqs != nstructs ../OMA_data/LUCA/HOG387/
# 58 89
# nseqs != nstructs ../OMA_data/LUCA/HOG815/
# 33 35
# nseqs != nstructs ../OMA_data/LUCA/HOG1084/
# 17 46
# nseqs != nstructs ../OMA_data/LUCA/HOG1081/
# 17 57
# nseqs != nstructs ../OMA_data/LUCA/HOG697/
# 50 55
# nseqs != nstructs ../OMA_data/LUCA/HOG211/
# 39 64
# nseqs != nstructs ../OMA_data/LUCA/HOG813/
# 11 12
# nseqs != nstructs ../OMA_data/LUCA/HOG255/
# 39 48
# nseqs != nstructs ../OMA_data/LUCA/HOG873/
# 21 26
# nseqs != nstructs ../OMA_data/LUCA/HOG279/
# 23 24
# nseqs != nstructs ../OMA_data/LUCA/HOG693/
# 71 77
# nseqs != nstructs ../OMA_data/LUCA/HOG760/
# 7 17
# nseqs != nstructs ../OMA_data/LUCA/HOG459/
# 25 47
# nseqs != nstructs ../OMA_data/LUCA/HOG506/
# 46 53
# nseqs != nstructs ../OMA_data/LUCA/HOG1079/
# 20 28
# nseqs != nstructs ../OMA_data/LUCA/HOG1132/
# 5 20
# nseqs != nstructs ../OMA_data/LUCA/HOG608/
# 43 61
# nseqs != nstructs ../OMA_data/LUCA/HOG945/
# 40 54
# nseqs != nstructs ../OMA_data/LUCA/HOG457/
# 20 25
# nseqs != nstructs ../OMA_data/LUCA/HOG1130/
# 28 52
# nseqs != nstructs ../OMA_data/LUCA/HOG606/
# 11 20
# nseqs != nstructs ../OMA_data/LUCA/HOG527/
# 3 12
# nseqs != nstructs ../OMA_data/LUCA/HOG1147/
# 16 21
# nseqs != nstructs ../OMA_data/LUCA/HOG339/
# 13 33
# nseqs != nstructs ../OMA_data/LUCA/HOG638/
# 9 53
# nseqs != nstructs ../OMA_data/LUCA/HOG9/
# 18 20
# nseqs != nstructs ../OMA_data/LUCA/HOG50/
# 16 18
# nseqs != nstructs ../OMA_data/LUCA/HOG1025/
# 7 12
# nseqs != nstructs ../OMA_data/LUCA/HOG987/
# 17 46
# nseqs != nstructs ../OMA_data/LUCA/HOG1015/
# 3 14
# nseqs != nstructs ../OMA_data/LUCA/HOG1343/
# 16 24
# nseqs != nstructs ../OMA_data/LUCA/HOG631/
# 44 54
# nseqs != nstructs ../OMA_data/LUCA/HOG1168/
# 43 52
# nseqs != nstructs ../OMA_data/LUCA/HOG148/
# 42 67
# nseqs != nstructs ../OMA_data/LUCA/HOG1053/
# 33 43
# lddt_1_raw_struct_tree sequences
# delta: 2730.0 delta norm: 2.5964208926385197 WilcoxonResult(statistic=330.0, pvalue=0.7454488506303837)
# fident_1_raw_struct_tree sequences
# delta: 3698.0 delta norm: 5.383009179517992 WilcoxonResult(statistic=111.0, pvalue=0.012352901274840983)
# alntmscore_1_raw_struct_tree sequences
# delta: 711.0 delta norm: -2.4191590724005803 WilcoxonResult(statistic=214.5, pvalue=0.06261254517387883)
# lddt_0_raw_struct_tree sequences
# delta: 2333.0 delta norm: 2.355662964403729 WilcoxonResult(statistic=350.5, pvalue=0.9879532282660395)
# fident_0_raw_struct_tree sequences
# delta: 2823.0 delta norm: 2.8625697880447056 WilcoxonResult(statistic=346.5, pvalue=0.9398244458320892)
# alntmscore_0_raw_struct_tree sequences
# delta: 655.0 delta norm: -2.1264671755900024 WilcoxonResult(statistic=246.0, pvalue=0.07186333944264334)
# ../OMA_data/Opisthokonta/
# ../OMA_data/Opisthokonta/
# 523
# processed: 520:  13%|█▎        | 70/523 [00:00<00:00, 599.78it/s]
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG227/
# 19 55
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG536/
# 14 16
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG395/
# 5 14
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG250/
# 20 23
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG573/
# 12 17
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG26/
# 69 110
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG20/
# 4 15
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG542/
# 25 27
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG110/
# 15 36
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG565/
# 20 21
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG309/
# 40 41
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG541/
# 11 32
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG522/
# 3 14
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG198/
# 7 15
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG448/
# 8 51
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG108/
# 7 23
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG547/
# 5 33
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG603/
# 7 15
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG414/
# 11 23
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG426/
# 5 35
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG373/
# 7 17
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG228/
# 10 17
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG245/
# 13 32
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG559/
# 7 20
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG85/
# 3 21
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG627/
# 6 16
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG514/
# 4 48
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG173/
# 33 46
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG123/
# 5 46
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG65/
# 9 13
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG140/
# 5 18
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG247/
# 9 39
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG5/
# 11 32
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG577/
# 22 31
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG371/
# 14 15
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG104/
# 7 34
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG549/
# 28 49
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG361/
# 24 27
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG77/
# 36 41
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG378/
# 11 42
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG67/
# 12 15
# nseqs != nstructs ../OMA_data/Opisthokonta/HOG652/
# 6 34
# lddt_1_raw_struct_tree sequences
# delta: -254.0 delta norm: -0.9622917515104655 WilcoxonResult(statistic=104.5, pvalue=0.07132513460936779)
# fident_1_raw_struct_tree sequences
# delta: 883.0 delta norm: 2.0858650015033433 WilcoxonResult(statistic=81.0, pvalue=0.13933855391960334)
# alntmscore_1_raw_struct_tree sequences
# delta: -1812.0 delta norm: -5.617192342011586 WilcoxonResult(statistic=28.0, pvalue=0.00029539281616763435)
# lddt_0_raw_struct_tree sequences
# delta: -357.0 delta norm: -1.1808179533631264 WilcoxonResult(statistic=101.5, pvalue=0.05935487151145935)
# fident_0_raw_struct_tree sequences
# delta: -928.0 delta norm: -3.5445013725057244 WilcoxonResult(statistic=60.0, pvalue=0.005816358945786271)
# alntmscore_0_raw_struct_tree sequences
# delta: -1614.0 delta norm: -4.932987050766724 WilcoxonResult(statistic=52.0, pvalue=0.002944408554702792)
# ../OMA_data/Tetrapoda/
# ../OMA_data/Tetrapoda/
# 359
# processed: 355:  12%|█▏        | 44/359 [00:00<00:00, 565.91it/s]
# nseqs != nstructs ../OMA_data/Tetrapoda/HOG337/
# 6 10
# nseqs != nstructs ../OMA_data/Tetrapoda/HOG299/
# 7 21
# nseqs != nstructs ../OMA_data/Tetrapoda/HOG186/
# 8 14
# nseqs != nstructs ../OMA_data/Tetrapoda/HOG343/
# 17 19
# nseqs != nstructs ../OMA_data/Tetrapoda/HOG357/
# 12 31
# nseqs != nstructs ../OMA_data/Tetrapoda/HOG170/
# 10 11
# nseqs != nstructs ../OMA_data/Tetrapoda/HOG308/
# 10 18
# nseqs != nstructs ../OMA_data/Tetrapoda/HOG256/
# 7 14
# nseqs != nstructs ../OMA_data/Tetrapoda/HOG284/
# 4 12
# nseqs != nstructs ../OMA_data/Tetrapoda/HOG95/
# 5 12
# nseqs != nstructs ../OMA_data/Tetrapoda/HOG285/
# 38 52
# nseqs != nstructs ../OMA_data/Tetrapoda/HOG307/
# 7 21
# nseqs != nstructs ../OMA_data/Tetrapoda/HOG317/
# 9 34
# nseqs != nstructs ../OMA_data/Tetrapoda/HOG212/
# 6 18
# nseqs != nstructs ../OMA_data/Tetrapoda/HOG166/
# 4 10
# nseqs != nstructs ../OMA_data/Tetrapoda/HOG33/
# 15 17
# nseqs != nstructs ../OMA_data/Tetrapoda/HOG181/
# 6 17
# nseqs != nstructs ../OMA_data/Tetrapoda/HOG48/
# 17 20
# nseqs != nstructs ../OMA_data/Tetrapoda/HOG127/
# 7 9
# nseqs != nstructs ../OMA_data/Tetrapoda/HOG73/
# 22 26
# lddt_1_raw_struct_tree sequences
# delta: 156.0 delta norm: 0.6525930454141604 WilcoxonResult(statistic=79.0, pvalue=0.5196142846604979)
# fident_1_raw_struct_tree sequences
# delta: 1216.0 delta norm: 2.0010855634158164 WilcoxonResult(statistic=11.0, pvalue=0.015746296328179612)
# alntmscore_1_raw_struct_tree sequences
# delta: -744.0 delta norm: -0.04363407286235475 WilcoxonResult(statistic=69.0, pvalue=0.10604443846627067)
# lddt_0_raw_struct_tree sequences
# delta: 66.0 delta norm: 0.5172265913904565 WilcoxonResult(statistic=66.0, pvalue=0.6190554886234496)
# fident_0_raw_struct_tree sequences
# delta: 154.0 delta norm: 0.21215717144831225 WilcoxonResult(statistic=80.5, pvalue=0.55942963865861)
# alntmscore_0_raw_struct_tree sequences
# delta: -552.0 delta norm: 0.09140031948200207 WilcoxonResult(statistic=71.5, pvalue=0.1260093247841567)
# ../OMA_data_unfiltered/OMA_data/Opisthokonta/
# ../OMA_data_unfiltered/OMA_data/Opisthokonta/
# 117
# processed: 117:  97%|█████████▋| 113/117 [00:00<00:00, 582.92it/s]
# lddt_1_raw_struct_tree sequences
# delta: -5522 delta norm: -14.067986738326223 WilcoxonResult(statistic=75.5, pvalue=4.546483746374684e-19)
# fident_1_raw_struct_tree sequences
# delta: -453 delta norm: -1.0694436606742335 WilcoxonResult(statistic=1909.0, pvalue=0.016566481429262564)
# alntmscore_1_raw_struct_tree sequences
# delta: -12018 delta norm: -31.238956875853464 WilcoxonResult(statistic=0.0, pvalue=4.0895490745846905e-20)
# lddt_0_raw_struct_tree sequences
# delta: -6163.0 delta norm: -15.974827335831014 WilcoxonResult(statistic=62.0, pvalue=4.709548631884231e-19)
# fident_0_raw_struct_tree sequences
# delta: -6301 delta norm: -16.3734732152187 WilcoxonResult(statistic=56.5, pvalue=6.019669203919761e-19)
# alntmscore_0_raw_struct_tree sequences
# delta: -12274 delta norm: -31.384958969884593 WilcoxonResult(statistic=0.0, pvalue=8.739104884597756e-20)
# ../OMA_data_unfiltered/OMA_data/Dikarya/
# ../OMA_data_unfiltered/OMA_data/Dikarya/
# 117
# processed: 117:  97%|█████████▋| 114/117 [00:00<00:00, 589.08it/s]
# lddt_1_raw_struct_tree sequences
# delta: -483 delta norm: -4.737156339866169 WilcoxonResult(statistic=433.5, pvalue=1.2874415203395138e-10)
# fident_1_raw_struct_tree sequences
# delta: -96 delta norm: -0.7781998447219263 WilcoxonResult(statistic=680.0, pvalue=0.006216525436965473)
# alntmscore_1_raw_struct_tree sequences
# delta: -1551 delta norm: -13.844731402320841 WilcoxonResult(statistic=26.5, pvalue=3.8118211672037435e-19)
# lddt_0_raw_struct_tree sequences
# delta: -557 delta norm: -5.830764365320746 WilcoxonResult(statistic=463.5, pvalue=1.4789074413809412e-11)
# fident_0_raw_struct_tree sequences
# delta: -578 delta norm: -5.658280549276288 WilcoxonResult(statistic=426.5, pvalue=9.350873299893427e-12)
# alntmscore_0_raw_struct_tree sequences
# delta: -1680 delta norm: -15.032585219423858 WilcoxonResult(statistic=61.0, pvalue=6.660214115265125e-19)
# ../OMA_data/Eukaryota/
# ../OMA_data/Eukaryota/
# 605
# processed: 605:  15%|█▌        | 93/605 [00:00<00:00, 598.64it/s]
# nseqs != nstructs ../OMA_data/Eukaryota/HOG615/
# 6 56
# nseqs != nstructs ../OMA_data/Eukaryota/HOG2393/
# 12 47
# nseqs != nstructs ../OMA_data/Eukaryota/HOG2945/
# 22 29
# nseqs != nstructs ../OMA_data/Eukaryota/HOG452/
# 94 97
# nseqs != nstructs ../OMA_data/Eukaryota/HOG2840/
# 14 44
# nseqs != nstructs ../OMA_data/Eukaryota/HOG133/
# 17 33
# nseqs != nstructs ../OMA_data/Eukaryota/HOG1607/
# 28 30
# nseqs != nstructs ../OMA_data/Eukaryota/HOG2660/
# 3 25
# nseqs != nstructs ../OMA_data/Eukaryota/HOG459/
# 13 48
# nseqs != nstructs ../OMA_data/Eukaryota/HOG2016/
# 12 32
# nseqs != nstructs ../OMA_data/Eukaryota/HOG1781/
# 30 35
# nseqs != nstructs ../OMA_data/Eukaryota/HOG2110/
# 24 35
# nseqs != nstructs ../OMA_data/Eukaryota/HOG3096/
# 16 25
# nseqs != nstructs ../OMA_data/Eukaryota/HOG554/
# 12 61
# nseqs != nstructs ../OMA_data/Eukaryota/HOG2360/
# 12 24
# nseqs != nstructs ../OMA_data/Eukaryota/HOG2240/
# 28 44
# nseqs != nstructs ../OMA_data/Eukaryota/HOG1059/
# 19 21
# nseqs != nstructs ../OMA_data/Eukaryota/HOG2586/
# 3 18
# nseqs != nstructs ../OMA_data/Eukaryota/HOG1071/
# 39 47
# nseqs != nstructs ../OMA_data/Eukaryota/HOG1140/
# 17 40
# nseqs != nstructs ../OMA_data/Eukaryota/HOG1705/
# 9 24
# nseqs != nstructs ../OMA_data/Eukaryota/HOG2822/
# 21 23
# nseqs != nstructs ../OMA_data/Eukaryota/HOG965/
# 8 25
# nseqs != nstructs ../OMA_data/Eukaryota/HOG540/
# 52 64
# nseqs != nstructs ../OMA_data/Eukaryota/HOG2635/
# 16 47
# nseqs != nstructs ../OMA_data/Eukaryota/HOG490/
# 32 44
# nseqs != nstructs ../OMA_data/Eukaryota/HOG2971/
# 3 21
# nseqs != nstructs ../OMA_data/Eukaryota/HOG1060/
# 28 45
# nseqs != nstructs ../OMA_data/Eukaryota/HOG1362/
# 17 66
# nseqs != nstructs ../OMA_data/Eukaryota/HOG2107/
# 32 36
# nseqs != nstructs ../OMA_data/Eukaryota/HOG2068/
# 4 26
# nseqs != nstructs ../OMA_data/Eukaryota/HOG1539/
# 6 19
# nseqs != nstructs ../OMA_data/Eukaryota/HOG981/
# 30 44
# nseqs != nstructs ../OMA_data/Eukaryota/HOG613/
# 32 51
# nseqs != nstructs ../OMA_data/Eukaryota/HOG2279/
# 7 30
# nseqs != nstructs ../OMA_data/Eukaryota/HOG110/
# 3 70
# nseqs != nstructs ../OMA_data/Eukaryota/HOG61/
# 13 46
# nseqs != nstructs ../OMA_data/Eukaryota/HOG679/
# 41 42
# nseqs != nstructs ../OMA_data/Eukaryota/HOG1084/
# 17 48
# nseqs != nstructs ../OMA_data/Eukaryota/HOG3192/
# 4 35
# nseqs != nstructs ../OMA_data/Eukaryota/HOG853/
# 48 130
# nseqs != nstructs ../OMA_data/Eukaryota/HOG1753/
# 35 39
# nseqs != nstructs ../OMA_data/Eukaryota/HOG100/
# 47 66
# nseqs != nstructs ../OMA_data/Eukaryota/HOG1551/
# 17 19
# nseqs != nstructs ../OMA_data/Eukaryota/HOG1433/
# 12 30
# nseqs != nstructs ../OMA_data/Eukaryota/HOG2859/
# 6 12
# nseqs != nstructs ../OMA_data/Eukaryota/HOG425/
# 3 44
# nseqs != nstructs ../OMA_data/Eukaryota/HOG248/
# 33 37
# nseqs != nstructs ../OMA_data/Eukaryota/HOG1827/
# 17 30
# nseqs != nstructs ../OMA_data/Eukaryota/HOG1627/
# 28 34
# nseqs != nstructs ../OMA_data/Eukaryota/HOG155/
# 49 58
# nseqs != nstructs ../OMA_data/Eukaryota/HOG129/
# 64 67
# nseqs != nstructs ../OMA_data/Eukaryota/HOG2670/
# 57 70
# nseqs != nstructs ../OMA_data/Eukaryota/HOG727/
# 20 36
# lddt_1_raw_struct_tree sequences
# delta: 1811.0 delta norm: -1.917153059239494 WilcoxonResult(statistic=114.0, pvalue=0.04266392954421394)
# fident_1_raw_struct_tree sequences
# delta: 4946.0 delta norm: 2.424057515344656 WilcoxonResult(statistic=161.0, pvalue=0.33868237462469764)
# alntmscore_1_raw_struct_tree sequences
# delta: -927.0 delta norm: -4.616812095733911 WilcoxonResult(statistic=108.0, pvalue=0.017897082542391966)
# lddt_0_raw_struct_tree sequences
# delta: 2333.0 delta norm: -1.6904123158269848 WilcoxonResult(statistic=116.5, pvalue=0.08151927387780179)
# fident_0_raw_struct_tree sequences
# delta: 2091.0 delta norm: -2.3447611425553627 WilcoxonResult(statistic=89.5, pvalue=0.028932707856921175)
# alntmscore_0_raw_struct_tree sequences
# delta: -1629.0 delta norm: -6.485224094543067 WilcoxonResult(statistic=84.0, pvalue=0.0038930850466589546)
# ../OMA_data/Euteleostomi/
# ../OMA_data/Euteleostomi/
# 1019
# processed: 1013:   3%|▎         | 34/1019 [00:00<00:02, 462.70it/s]
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/miniconda3/envs/ML2/lib/python3.10/site-packages/scipy/stats/_morestats.py:3351: UserWarning:
#
# Sample size too small for normal approximation.
# nseqs != nstructs ../OMA_data/Euteleostomi/HOG453/
# 5 10
# nseqs != nstructs ../OMA_data/Euteleostomi/HOG1822/
# 9 11
# nseqs != nstructs ../OMA_data/Euteleostomi/HOG201/
# 3 14
# nseqs != nstructs ../OMA_data/Euteleostomi/HOG3087/
# 3 10
# nseqs != nstructs ../OMA_data/Euteleostomi/HOG1024/
# 5 26
# nseqs != nstructs ../OMA_data/Euteleostomi/HOG1567/
# 9 14
# nseqs != nstructs ../OMA_data/Euteleostomi/HOG2010/
# 8 12
# nseqs != nstructs ../OMA_data/Euteleostomi/HOG1889/
# 41 43
# nseqs != nstructs ../OMA_data/Euteleostomi/HOG2204/
# 3 10
# nseqs != nstructs ../OMA_data/Euteleostomi/HOG2330/
# 49 92
# nseqs != nstructs ../OMA_data/Euteleostomi/HOG1803/
# 3 13
# nseqs != nstructs ../OMA_data/Euteleostomi/HOG1730/
# 5 11
# nseqs != nstructs ../OMA_data/Euteleostomi/HOG1020/
# 3 10
# nseqs != nstructs ../OMA_data/Euteleostomi/HOG2357/
# 12 18
# nseqs != nstructs ../OMA_data/Euteleostomi/HOG955/
# 4 17
# nseqs != nstructs ../OMA_data/Euteleostomi/HOG2464/
# 7 10
# nseqs != nstructs ../OMA_data/Euteleostomi/HOG2072/
# 5 10
# lddt_1_raw_struct_tree sequences
# delta: -97.0 delta norm: -0.661991173674148 WilcoxonResult(statistic=19.5, pvalue=0.06904314057509947)
# fident_1_raw_struct_tree sequences
# delta: 72.0 delta norm: 0.26021563344664944 WilcoxonResult(statistic=12.0, pvalue=0.7353166906373405)
# alntmscore_1_raw_struct_tree sequences
# delta: -281.0 delta norm: -1.5720304830685898 WilcoxonResult(statistic=18.0, pvalue=0.030123644381970006)
# lddt_0_raw_struct_tree sequences
# delta: -137.0 delta norm: -0.9878844663482803 WilcoxonResult(statistic=21.0, pvalue=0.04776982928536977)
# fident_0_raw_struct_tree sequences
# delta: -144.0 delta norm: -0.864810577298868 WilcoxonResult(statistic=20.0, pvalue=0.041076902906488105)
# alntmscore_0_raw_struct_tree sequences
# delta: -318.0 delta norm: -1.732096002801124 WilcoxonResult(statistic=18.0, pvalue=0.01507568359375)
# ../OMA_data_unfiltered/OMA_data/Chordata/
# ../OMA_data_unfiltered/OMA_data/Chordata/
# 117
# processed: 117:  95%|█████████▍| 111/117 [00:00<00:00, 569.73it/s]
# lddt_1_raw_struct_tree sequences
# delta: -6232 delta norm: -10.79071640780462 WilcoxonResult(statistic=44.5, pvalue=6.711107340815181e-18)
# fident_1_raw_struct_tree sequences
# delta: 418 delta norm: -0.10763726476535168 WilcoxonResult(statistic=1491.5, pvalue=0.19022995118882124)
# alntmscore_1_raw_struct_tree sequences
# delta: -11374 delta norm: -20.349874884836407 WilcoxonResult(statistic=21.5, pvalue=4.988597220619484e-19)
# lddt_0_raw_struct_tree sequences
# delta: -6683 delta norm: -12.58742892552827 WilcoxonResult(statistic=61.5, pvalue=7.404699905275916e-18)
# fident_0_raw_struct_tree sequences
# delta: -6298 delta norm: -12.098890837149566 WilcoxonResult(statistic=101.5, pvalue=2.3137636711499988e-17)
# alntmscore_0_raw_struct_tree sequences
# delta: -11812 delta norm: -20.943144035245233 WilcoxonResult(statistic=23.0, pvalue=3.5414859358495327e-19)
# ../OMA_data_unfiltered/OMA_data/Euteleostomi/
# ../OMA_data_unfiltered/OMA_data/Euteleostomi/
# 117
# processed: 117:  95%|█████████▍| 111/117 [00:00<00:00, 590.11it/s]
# lddt_1_raw_struct_tree sequences
# delta: -2427.0 delta norm: -11.17293495662632 WilcoxonResult(statistic=6.0, pvalue=1.0061571055297508e-18)
# fident_1_raw_struct_tree sequences
# delta: -255 delta norm: -0.8616182775575233 WilcoxonResult(statistic=811.5, pvalue=0.0002703585114869425)
# alntmscore_1_raw_struct_tree sequences
# delta: -4342.0 delta norm: -18.124896541743443 WilcoxonResult(statistic=1.0, pvalue=8.726909951584347e-19)
# lddt_0_raw_struct_tree sequences
# delta: -2734 delta norm: -12.596929470259019 WilcoxonResult(statistic=7.5, pvalue=4.893555516865442e-19)
# fident_0_raw_struct_tree sequences
# delta: -2759 delta norm: -12.905576977628678 WilcoxonResult(statistic=5.0, pvalue=3.115352754919231e-19)
# alntmscore_0_raw_struct_tree sequences
# delta: -4041 delta norm: -17.88636060404469 WilcoxonResult(statistic=0.0, pvalue=5.798526003468689e-19)
# ../OMA_data/Fungi/
# ../OMA_data/Fungi/
# 138
# processed: 133:  24%|██▍       | 33/138 [00:00<00:00, 599.72it/s]
# nseqs != nstructs ../OMA_data/Fungi/HOG110/
# 6 12
# nseqs != nstructs ../OMA_data/Fungi/HOG85/
# 9 11
# nseqs != nstructs ../OMA_data/Fungi/HOG136/
# 3 12
# nseqs != nstructs ../OMA_data/Fungi/HOG127/
# 9 14
# nseqs != nstructs ../OMA_data/Fungi/HOG49/
# 7 11
# nseqs != nstructs ../OMA_data/Fungi/HOG116/
# 8 13
# nseqs != nstructs ../OMA_data/Fungi/HOG3/
# 5 11
# nseqs != nstructs ../OMA_data/Fungi/HOG108/
# 5 12
# nseqs != nstructs ../OMA_data/Fungi/HOG28/
# 3 31
# nseqs != nstructs ../OMA_data/Fungi/HOG92/
# 10 12
# nseqs != nstructs ../OMA_data/Fungi/HOG88/
# 11 13
# nseqs != nstructs ../OMA_data/Fungi/HOG129/
# 5 13
# nseqs != nstructs ../OMA_data/Fungi/HOG113/
# 10 12
# nseqs != nstructs ../OMA_data/Fungi/HOG137/
# 4 11
# nseqs != nstructs ../OMA_data/Fungi/HOG99/
# 6 12
# nseqs != nstructs ../OMA_data/Fungi/HOG101/
# 6 13
# nseqs != nstructs ../OMA_data/Fungi/HOG87/
# 10 12
# lddt_1_raw_struct_tree sequences
# delta: 72 delta norm: 0.5763855093734389 WilcoxonResult(statistic=50.0, pvalue=0.8751996893303613)
# fident_1_raw_struct_tree sequences
# delta: 155 delta norm: 1.604314730155423 WilcoxonResult(statistic=23.5, pvalue=0.12256476432546977)
# alntmscore_1_raw_struct_tree sequences
# delta: -23 delta norm: -0.510521168865471 WilcoxonResult(statistic=36.5, pvalue=0.1817067607219387)
# lddt_0_raw_struct_tree sequences
# delta: 109.0 delta norm: 0.9342546764164394 WilcoxonResult(statistic=40.5, pvalue=0.7265272954412638)
# fident_0_raw_struct_tree sequences
# delta: 62.0 delta norm: 0.3063082790297448 WilcoxonResult(statistic=43.5, pvalue=0.5717974534440897)
# alntmscore_0_raw_struct_tree sequences
# delta: 12.0 delta norm: 0.11671715226179863 WilcoxonResult(statistic=30.5, pvalue=0.5047392591799146)
# ../OMA_data_unfiltered/OMA_data/Tetrapoda/
# ../OMA_data_unfiltered/OMA_data/Tetrapoda/
# 117
# processed: 117:  97%|█████████▋| 114/117 [00:00<00:00, 585.08it/s]
# lddt_1_raw_struct_tree sequences
# delta: -3081.0 delta norm: -8.176597135459588 WilcoxonResult(statistic=40.5, pvalue=1.240671691634856e-18)
# fident_1_raw_struct_tree sequences
# delta: 36 delta norm: -0.008101434306240343 WilcoxonResult(statistic=1350.0, pvalue=0.4383819350235051)
# alntmscore_1_raw_struct_tree sequences
# delta: -6037 delta norm: -15.032725396369672 WilcoxonResult(statistic=3.0, pvalue=4.411481040413597e-20)
# lddt_0_raw_struct_tree sequences
# delta: -3482.0 delta norm: -9.987566740995376 WilcoxonResult(statistic=25.0, pvalue=8.051524108513897e-19)
# fident_0_raw_struct_tree sequences
# delta: -3036 delta norm: -9.646566037578381 WilcoxonResult(statistic=74.5, pvalue=3.2159712234952087e-18)
# alntmscore_0_raw_struct_tree sequences
# delta: -5826 delta norm: -14.661461279502625 WilcoxonResult(statistic=3.0, pvalue=4.417425709214461e-20)
# ../OMA_data/Chordata/
# ../OMA_data/Chordata/
# 786
# processed: 779:   5%|▌         | 40/786 [00:00<00:01, 486.44it/s]
# nseqs != nstructs ../OMA_data/Chordata/HOG205/
# 30 32
# nseqs != nstructs ../OMA_data/Chordata/HOG889/
# 12 13
# nseqs != nstructs ../OMA_data/Chordata/HOG191/
# 28 29
# nseqs != nstructs ../OMA_data/Chordata/HOG549/
# 8 12
# nseqs != nstructs ../OMA_data/Chordata/HOG12/
# 16 23
# nseqs != nstructs ../OMA_data/Chordata/HOG1003/
# 7 22
# nseqs != nstructs ../OMA_data/Chordata/HOG194/
# 9 11
# nseqs != nstructs ../OMA_data/Chordata/HOG181/
# 5 8
# nseqs != nstructs ../OMA_data/Chordata/HOG27/
# 8 14
# nseqs != nstructs ../OMA_data/Chordata/HOG303/
# 31 33
# nseqs != nstructs ../OMA_data/Chordata/HOG260/
# 21 28
# nseqs != nstructs ../OMA_data/Chordata/HOG10/
# 327 839
# nseqs != nstructs ../OMA_data/Chordata/HOG1004/
# 5 12
# nseqs != nstructs ../OMA_data/Chordata/HOG30/
# 38 60
# nseqs != nstructs ../OMA_data/Chordata/HOG411/
# 4 28
# nseqs != nstructs ../OMA_data/Chordata/HOG43/
# 14 42
# nseqs != nstructs ../OMA_data/Chordata/HOG981/
# 13 37
# lddt_1_raw_struct_tree sequences
# delta: 6373.0 delta norm: 1.8402377663850555 WilcoxonResult(statistic=89.0, pvalue=0.8092039689931078)
# fident_1_raw_struct_tree sequences
# delta: 7348.0 delta norm: 3.4874996576961124 WilcoxonResult(statistic=44.5, pvalue=0.07396401547262925)
# alntmscore_1_raw_struct_tree sequences
# delta: 4669.0 delta norm: 0.5844427022370401 WilcoxonResult(statistic=90.0, pvalue=0.5754529518891389)
# lddt_0_raw_struct_tree sequences
# delta: 6323.0 delta norm: 1.762526384032164 WilcoxonResult(statistic=97.0, pvalue=0.7651785898104478)
# fident_0_raw_struct_tree sequences
# delta: 6213.0 delta norm: 1.3186250052394068 WilcoxonResult(statistic=101.0, pvalue=0.8812824436000936)
# alntmscore_0_raw_struct_tree sequences
# delta: 4366.0 delta norm: 0.07463764541611714 WilcoxonResult(statistic=93.0, pvalue=0.43418687955840585)
# ../OMA_data_unfiltered/OMA_data/Fungi/
# ../OMA_data_unfiltered/OMA_data/Fungi/
# 117
# processed: 117:  98%|█████████▊| 115/117 [00:00<00:00, 589.68it/s]
# lddt_1_raw_struct_tree sequences
# delta: -592 delta norm: -7.2786615406735615 WilcoxonResult(statistic=506.0, pvalue=6.092837950765179e-12)
# fident_1_raw_struct_tree sequences
# delta: -154 delta norm: -1.808024994849524 WilcoxonResult(statistic=1471.0, pvalue=0.0025884472270672116)
# alntmscore_1_raw_struct_tree sequences
# delta: -1461.0 delta norm: -17.36110274994524 WilcoxonResult(statistic=52.5, pvalue=3.5687417597889904e-19)
# lddt_0_raw_struct_tree sequences
# delta: -545.0 delta norm: -6.591676608544575 WilcoxonResult(statistic=773.5, pvalue=1.2869529389711152e-10)
# fident_0_raw_struct_tree sequences
# delta: -748.0 delta norm: -9.037207959332573 WilcoxonResult(statistic=435.0, pvalue=9.567328501105902e-14)
# alntmscore_0_raw_struct_tree sequences
# delta: -1387.0 delta norm: -16.421209912778675 WilcoxonResult(statistic=140.0, pvalue=2.4235380608990714e-18)
# ../OMA_data_unfiltered/OMA_data/LUCA/
# ../OMA_data_unfiltered/OMA_data/LUCA/
# 117
# processed: 117: 100%|██████████| 117/117 [00:00<00:00, 580.20it/s]
# lddt_1_raw_struct_tree sequences
# delta: -3850 delta norm: -9.797833304981905 WilcoxonResult(statistic=404.0, pvalue=2.7445975827197957e-15)
# fident_1_raw_struct_tree sequences
# delta: -685 delta norm: -1.8135202179940975 WilcoxonResult(statistic=1219.0, pvalue=2.5670853039286146e-06)
# alntmscore_1_raw_struct_tree sequences
# delta: -11403 delta norm: -32.205668263273765 WilcoxonResult(statistic=76.0, pvalue=1.4004081780980538e-19)
# lddt_0_raw_struct_tree sequences
# delta: -3855 delta norm: -9.806766220011333 WilcoxonResult(statistic=430.0, pvalue=1.3201129735585306e-14)
# fident_0_raw_struct_tree sequences
# delta: -3703 delta norm: -10.153671310638865 WilcoxonResult(statistic=382.0, pvalue=2.6193493770921035e-16)
# alntmscore_0_raw_struct_tree sequences
# delta: -11297 delta norm: -31.83888745540133 WilcoxonResult(statistic=75.5, pvalue=1.379469046841418e-19)

# %%
#plt the OMA clades w and without filtering 
#plot the cat and cath and total oma with and without filtering

# %%
#construct structure and sequence feature dataset

def ret_description(vec , label = ''):
    return { label+'_mean': np.mean(vec) , label+'_max': np.amax(vec) , label+'_min': np.amin(vec) ,label+'_var': np.var(vec) }

allfolders = glob.glob(cladefolders)
dfs = []
print(allfolders)
for clade in allfolders:
    print(clade)
    res = {}
    folders = glob.glob(clade + '*/' )
    for folder in folders:
        if os.path.isfile(folder + 'plddt.json' ) and os.path.isfile(folder + 'sequence_dataset.csv' ) :
            plddt_df = pd.read_json(folder + 'plddt.json').T
            if len(plddt_df)>0:
                try:
                    plddt_df.columns = 'nobs,minmax,mean,variance,skewness,kurtosis'.split(',')
                    plddt_df['min'] = plddt_df.minmax.map( lambda r: r[0] )
                    plddt_df['max'] = plddt_df.minmax.map( lambda r: r[1] )
                    res[folder] = {}
                    for col in ['nobs', 'min' , 'max' , 'mean' , 'variance' , 'skewness' , 'kurtosis' ]:
                        descriptors = ret_description(plddt_df[col] , label = col)
                        for l in descriptors:
                            res[folder][l] = descriptors[l]
                    #add in some descriptors of the taxonomic spread and sequence set
                    seqdf = pd.read_csv(folder+'sequence_dataset.csv' )
                    res[folder]['nprots'] = len(seqdf)
                    cladesets = [ set(l.split(',')) for l in  seqdf['Taxonomic lineage (Ids)'] ]
                    union_all = cladesets[0]
                    intersection_all = cladesets[0]
                    for c in cladesets:
                        union_all = union_all.union(c)
                        intersection_all.intersection(c)
                    res[folder]['n_clades'] = len(union_all)
                    res[folder]['inter_clades'] = len(intersection_all)
                    res[folder]['inter/nc'] =  res[folder]['inter_clades'] /  res[folder]['n_clades'] 
                    res[folder]['nc/np'] = res[folder]['nprots'] / res[folder]['n_clades']
                except:
                    pass
    resdf = pd.DataFrame.from_dict(res, orient = 'index')
    dfs.append(resdf)
seqset_resdf = pd.concat(dfs)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 6
#       3 def ret_description(vec , label = ''):
#       4     return { label+'_mean': np.mean(vec) , label+'_max': np.amax(vec) , label+'_min': np.amin(vec) ,label+'_var': np.var(vec) }
# ----> 6 allfolders = glob.glob(cladefolders)
#       7 dfs = []
#       8 print(allfolders)
#
# File /work/FAC/FBM/DBC/cdessim2/default/dmoi/miniconda3/envs/ML2/lib/python3.10/glob.py:24, in glob(pathname, root_dir, dir_fd, recursive)
#      13 def glob(pathname, *, root_dir=None, dir_fd=None, recursive=False):
#      14     """Return a list of paths matching a pathname pattern.
#      15
#      16     The pattern may contain simple shell-style wildcards a la
#    (...)
#      22     zero or more directories and subdirectories.
#      23     """
# ---> 24     return list(iglob(pathname, root_dir=root_dir, dir_fd=dir_fd, recursive=recursive))
#
# File /work/FAC/FBM/DBC/cdessim2/default/dmoi/miniconda3/envs/ML2/lib/python3.10/glob.py:42, in iglob(pathname, root_dir, dir_fd, recursive)
#      40     root_dir = os.fspath(root_dir)
#      41 else:
# ---> 42     root_dir = pathname[:0]
#      43 it = _iglob(pathname, root_dir, dir_fd, recursive, False)
#      44 if not pathname or recursive and _isrecursive(pathname[:2]):
#
# TypeError: 'set' object is not subscriptable

# %%
print(seqset_resdf)
seqset_resdf.to_csv('structure_and_sequence_qcmetrics.csv')
# Out:
#                                                       nobs_mean  nobs_max  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...   807.250000       985
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...   521.944444       811
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...   401.434783       516
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    64.357143        71
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...   204.133333       215
# ...                                                         ...       ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  1041.034884      1191
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...   446.782609       581
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...   351.106061       480
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...   384.966102       506
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...   890.472222      1124
#
#                                                     nobs_min     nobs_var  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       642  9765.520833
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       447  5585.830247
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       277  1294.463138
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...        56    29.086735
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       191    56.382222
# ...                                                      ...          ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       667  3364.382504
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       290  6449.561437
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       187  3556.579660
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       274  2674.575122
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       557  8787.915895
#
#                                                      min_mean  min_max  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  34.624167    53.28
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  33.694444    49.47
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  35.808913    47.16
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  67.612143    74.96
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  37.811333    60.66
# ...                                                       ...      ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  26.432907    49.84
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  27.608261    35.90
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  27.326364    60.81
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  27.073898    33.50
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  31.714167    62.62
#
#                                                     min_min     min_var  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    24.20   60.249258
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    23.28   35.850047
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    28.72   24.900805
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    61.63   17.622931
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    20.38  103.666985
# ...                                                     ...         ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    20.27   35.795802
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    24.58    6.491693
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    19.63   65.113332
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    21.31    8.618786
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    19.72  171.468774
#
#                                                      max_mean  max_max  ...  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  98.885000    98.95  ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  98.288333    98.78  ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  98.446957    98.88  ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  96.832143    97.92  ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  92.832667    98.85  ...
# ...                                                       ...      ...  ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  98.867791    98.96  ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  98.164783    98.50  ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  98.747424    98.89  ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  97.897119    98.86  ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  98.943611    99.00  ...
#
#                                                     skewness_var  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0.676739
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0.436234
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0.387872
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0.391886
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      1.933084
# ...                                                          ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0.622155
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0.194253
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0.772692
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0.291286
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      1.928180
#
#                                                     kurtosis_mean  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      19.837862
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       5.764221
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       7.879371
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       4.578632
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       8.192775
# ...                                                           ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      11.438603
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      -1.477518
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       1.470316
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      -0.555410
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      18.847422
#
#                                                     kurtosis_max  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     34.363297
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     12.669195
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     21.380946
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     14.923462
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     21.343251
# ...                                                          ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     27.295166
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0.096212
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     35.943302
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      1.861041
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     35.672303
#
#                                                     kurtosis_min  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      9.844506
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     -1.358798
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0.084182
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     -0.079853
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     -0.571496
# ...                                                          ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0.971629
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     -1.811054
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     -1.774900
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     -1.762139
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      1.241103
#
#                                                     kurtosis_var  nprots  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     57.878212      12
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     12.864899      18
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     17.109750      46
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     14.677287      14
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     46.462987      15
# ...                                                          ...     ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     41.532549      87
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0.239959      23
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     34.498932      66
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      1.096213      59
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    143.677776      36
#
#                                                     n_clades  inter_clades  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      43.0          10.0
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      43.0          11.0
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      97.0           8.0
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      83.0           8.0
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      48.0          11.0
# ...                                                      ...           ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     378.0          30.0
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     164.0          13.0
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     211.0          13.0
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     292.0          30.0
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     247.0          30.0
#
#                                                     inter/nc     nc/np
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.232558  0.279070
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.255814  0.418605
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.082474  0.474227
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.096386  0.168675
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.229167  0.312500
# ...                                                      ...       ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.079365  0.230159
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.079268  0.140244
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.061611  0.312796
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.102740  0.202055
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.121457  0.145749
#
# [13424 rows x 33 columns]

# %%
#add to the tree comparison data
tree_resdf = tree_resdf.merge( seqset_resdf , left_index = True, right_index = True, how = 'inner' )
print(tree_resdf)
# Out:
#                                                     struct_tree.nwk.PP.nwk.rooted  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                             52
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                             76
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                            141
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                             33
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                             59
# ...                                                                           ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                           1022
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                            123
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                            642
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                            660
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                            462
#
#                                                     core_tree.nwk.PP.nwk.rooted  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                           52
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                           76
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                          141
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                           33
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                           59
# ...                                                                         ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                         1022
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                          123
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                          642
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                          660
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                          462
#
#                                                     sequences.aln.fst.nwk.rooted  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                            47
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                            76
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                           140
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                            33
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                            42
# ...                                                                          ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                          1054
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                           137
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                           679
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                           686
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                           461
#
#                                                     delta   max  delta_norm  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      5    52    0.096154
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0    76    0.000000
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      1   141    0.007092
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0    33    0.000000
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     17    59    0.288136
# ...                                                   ...   ...         ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    -32  1054   -0.030361
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    -14   137   -0.102190
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    -37   679   -0.054492
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    -26   686   -0.037901
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      1   462    0.002165
#
#                                                                                                 clade  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  /work/FAC/FBM/DBC/cdessim2/default/dmoi/datase...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  /work/FAC/FBM/DBC/cdessim2/default/dmoi/datase...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  /work/FAC/FBM/DBC/cdessim2/default/dmoi/datase...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  /work/FAC/FBM/DBC/cdessim2/default/dmoi/datase...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  /work/FAC/FBM/DBC/cdessim2/default/dmoi/datase...
# ...                                                                                               ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  /work/FAC/FBM/DBC/cdessim2/default/dmoi/datase...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  /work/FAC/FBM/DBC/cdessim2/default/dmoi/datase...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  /work/FAC/FBM/DBC/cdessim2/default/dmoi/datase...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  /work/FAC/FBM/DBC/cdessim2/default/dmoi/datase...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  /work/FAC/FBM/DBC/cdessim2/default/dmoi/datase...
#
#                                                    HOG    nobs_mean  nobs_max  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       807.250000       985
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       521.944444       811
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       401.434783       516
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...        64.357143        71
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       204.133333       215
# ...                                                 ..          ...       ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      1041.034884      1191
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       446.782609       581
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       351.106061       480
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       384.966102       506
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       890.472222      1124
#
#                                                     ...  skewness_var  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  ...      0.676739
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  ...      0.436234
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  ...      0.387872
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  ...      0.391886
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  ...      1.933084
# ...                                                 ...           ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  ...      0.622155
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  ...      0.194253
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  ...      0.772692
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  ...      0.291286
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  ...      1.928180
#
#                                                     kurtosis_mean  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      19.837862
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       5.764221
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       7.879371
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       4.578632
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       8.192775
# ...                                                           ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      11.438603
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      -1.477518
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       1.470316
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      -0.555410
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      18.847422
#
#                                                     kurtosis_max  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     34.363297
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     12.669195
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     21.380946
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     14.923462
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     21.343251
# ...                                                          ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     27.295166
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0.096212
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     35.943302
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      1.861041
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     35.672303
#
#                                                     kurtosis_min  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      9.844506
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     -1.358798
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0.084182
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     -0.079853
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     -0.571496
# ...                                                          ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0.971629
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     -1.811054
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     -1.774900
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     -1.762139
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      1.241103
#
#                                                     kurtosis_var  nprots  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     57.878212      12
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     12.864899      18
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     17.109750      46
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     14.677287      14
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     46.462987      15
# ...                                                          ...     ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     41.532549      87
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0.239959      23
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     34.498932      66
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      1.096213      59
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    143.677776      36
#
#                                                     n_clades  inter_clades  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      43.0          10.0
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      43.0          11.0
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      97.0           8.0
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      83.0           8.0
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      48.0          11.0
# ...                                                      ...           ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     378.0          30.0
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     164.0          13.0
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     211.0          13.0
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     292.0          30.0
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     247.0          30.0
#
#                                                     inter/nc     nc/np
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.232558  0.279070
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.255814  0.418605
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.082474  0.474227
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.096386  0.168675
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.229167  0.312500
# ...                                                      ...       ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.079365  0.230159
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.079268  0.140244
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.061611  0.312796
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.102740  0.202055
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.121457  0.145749
#
# [8967 rows x 41 columns]

# %%
print(tree_resdf.columns)
# Out:
# Index(['struct_tree.nwk.PP.nwk.rooted', 'core_tree.nwk.PP.nwk.rooted',
#        'sequences.aln.fst.nwk.rooted', 'delta', 'max', 'delta_norm', 'clade',
#        'HOG', 'nobs_mean', 'nobs_max', 'nobs_min', 'nobs_var', 'min_mean',
#        'min_max', 'min_min', 'min_var', 'max_mean', 'max_max', 'max_min',
#        'max_var', 'mean_mean', 'mean_max', 'mean_min', 'mean_var',
#        'variance_mean', 'variance_max', 'variance_min', 'variance_var',
#        'skewness_mean', 'skewness_max', 'skewness_min', 'skewness_var',
#        'kurtosis_mean', 'kurtosis_max', 'kurtosis_min', 'kurtosis_var',
#        'nprots', 'n_clades', 'inter_clades', 'inter/nc', 'nc/np'],
#       dtype='object')

# %%
#try to predict the delta using these features w gradient boosted trees
#try to predict the RF distance as well

import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, ensemble
from sklearn.inspection import permutation_importance
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
X, y = tree_resdf[['nobs_mean', 'nobs_max',
       'nobs_min', 'nobs_var', 'min_mean', 'min_max', 'min_min', 'min_var',
       'max_mean', 'max_max', 'max_min', 'max_var', 'mean_mean', 'mean_max',
       'mean_min', 'mean_var', 'variance_mean', 'variance_max', 'variance_min',
       'variance_var', 'skewness_mean', 'skewness_max', 'skewness_min',
       'skewness_var', 'kurtosis_mean', 'kurtosis_max', 'kurtosis_min',
       'kurtosis_var', 'nprots', 'n_clades', 'inter_clades', 'inter/nc',
       'nc/np']], tree_resdf.delta_norm

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.1, random_state=13
)

params = {
    "n_estimators": 500,
    "max_depth": 4,
    "min_samples_split": 5,
    "learning_rate": 0.01,
    "loss": "squared_error",
}


reg = ensemble.GradientBoostingRegressor(**params)
reg.fit(X_train, y_train)

mse = mean_squared_error(y_test, reg.predict(X_test))
print("The mean squared error (MSE) on test set: {:.4f}".format(mse))

test_score = np.zeros((params["n_estimators"],), dtype=np.float64)
for i, y_pred in enumerate(reg.staged_predict(X_test)):
    test_score[i] = mean_squared_error(y_test, y_pred)
# Out:
# The mean squared error (MSE) on test set: 0.0042

# %%
fig = plt.figure(figsize=(6, 6))
plt.subplot(1, 1, 1)
plt.title("Deviance")
plt.plot(
    np.arange(params["n_estimators"]) + 1,
    reg.train_score_,
    "b-",
    label="Training Set Deviance",
)
plt.plot(
    np.arange(params["n_estimators"]) + 1, test_score, "r-", label="Test Set Deviance"
)
plt.legend(loc="upper right")
plt.xlabel("Boosting Iterations")
plt.ylabel("Deviance")
fig.tight_layout()
plt.show()

# %%
feature_importance = reg.feature_importances_
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + 0.5
fig = plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.barh(pos, feature_importance[sorted_idx], align="center")
plt.yticks(pos, np.array(X.columns)[sorted_idx])
plt.title("Feature Importance (MDI)")

result = permutation_importance(
    reg, X_test, y_test, n_repeats=10, random_state=42, n_jobs=2
)
sorted_idx = result.importances_mean.argsort()
plt.subplot(1, 2, 2)
plt.boxplot(
    result.importances[sorted_idx].T,
    vert=False,
    labels=np.array(X.columns)[sorted_idx],
)
plt.title("Permutation Importance (test set)")
fig.tight_layout()
plt.show()
