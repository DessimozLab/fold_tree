# %%
import json
import seaborn as sns
import glob
import os
import numpy as np

# %%
import pandas as pd
import tqdm
import itertools
i =0
cladefolders = '../CATH_data/'
allfolders = glob.glob(cladefolders)
dfs = []
print(allfolders)
#scorefunc = 'score'
scorefunc = 'red_x_score'

for clade in allfolders:
    print(clade)
    res = {}
    folders = set(glob.glob(clade + '*/' ))-set([clade+'logs/'])
    with tqdm.tqdm(total=len(folders)) as pbar:
        for i,folder in enumerate(folders):                
            nstructs = len(glob.glob(folder+'structs/*.pdb'))
            if os.path.isfile(folder+'treescores_sequences.json'):
                treescores = glob.glob(folder + '*_treescores_struct_tree.json' ) +[folder+'treescores_sequences.json']
                if len(treescores)>0 and os.path.isfile(folder + 'sequences.fst'):
                    with open(folder + 'sequences.fst') as fstin:
                        nseqs = fstin.read().count('>')
                    #pbar.set_description('processed: %d' % (1 + i))
                    #pbar.update(1)
                    #if nseqs == nstructs :
                    print(nseqs , nstructs )
                    for score in treescores:
                        with open(score) as taxin:
                            tax_res = json.load(taxin)
                        tax_res= {s.split('/')[-1]:tax_res[s] for s in tax_res}
                        if folder not in res:
                            res[folder] = { s:tax_res[s][scorefunc] for s in tax_res if  scorefunc  in tax_res[s]}
                        else:
                            res[folder].update({ s:tax_res[s][scorefunc] for s in tax_res if scorefunc in tax_res[s]})
    if len(res)>0:
        resdf = pd.DataFrame.from_dict(res, orient = 'index')
        resdf.columns = [ c.replace('.PP.nwk.rooted', '').replace('.aln.fst.nwk.rooted' , '' ) for c in  resdf.columns]
        refclols = resdf.columns
        for c1,c2 in itertools.combinations(resdf.columns,2):
            resdf[c1+'_'+c2+'_delta'] = resdf[c1] - resdf[c2] 
            resdf[c1+'_'+c2+'_max'] = resdf[[c1,c2]].apply( max , axis = 1) 
            resdf[c1+'_'+c2+'_delta_norm'] = resdf[c1+'_'+c2+'_delta'] / resdf[c1+'_'+c2+'_max']
        resdf['clade'] = clade
        resdf['HOG'] = folder.split('/')[-1]
        dfs.append(resdf)
tree_resdf = pd.concat(dfs)
# Out:
# ['../CATH_data/']
# ../CATH_data/
#   0%|          | 0/101 [00:00<?, ?it/s]
# 66 66
# 43 43
# 94 94
# 159 159
# 111 111
# 71 71
# 14 14
# 38 38
# 51 51
# 6 6
# 5 5
# 93 93
# 15 15
# 12 12
# 16 16
# 12 12
# 8 8
# 67 67
# 3 3
# 16 16
# 4 4
# 97 97
# 40 40
# 47 47
# 16 16
# 31 31
# 12 12
# 41 41
# 33 33
# 55 55
# 22 22
# 38 38
# 16 16
# 57 57
# 61 61
# 44 44
# 68 68
# 1 1
# 26 26
# 76 76
# 4 4
# 34 34
# 1 1
# 60 60
# 29 29
# 65 65
# 61 61
# 31 31
# 1 1
# 8 8
# 95 95
# 20 20
# 23 23
# 12 12
# 98 98
# 32 32
# 1 1
# 43 43
# 1 1
# 8 8
# 58 58
# 22 22

# %%
print(tree_resdf)
# Out:
#                             alntmscore_0_raw_struct_tree  \
# ../CATH_data/1.10.490.10/                   9.924481e+01
# ../CATH_data/3.40.1190.20/                  1.848886e+01
# ../CATH_data/3.40.30.10/                    4.284206e+01
# ../CATH_data/3.40.50.720/                   6.143049e+01
# ../CATH_data/3.20.20.70/                    4.001970e+01
# ../CATH_data/3.90.180.10/                   3.060742e+01
# ../CATH_data/3.10.20.90/                    7.262693e+00
# ../CATH_data/3.40.50.880/                   1.740522e+01
# ../CATH_data/3.30.70.100/                   3.331326e+01
# ../CATH_data/1.10.8.60/                     1.134766e+01
# ../CATH_data/2.30.42.10/                    8.103345e+00
# ../CATH_data/3.30.360.10/                   2.654732e+01
# ../CATH_data/2.80.10.50/                    2.594379e+01
# ../CATH_data/3.30.450.20/                   6.484800e+00
# ../CATH_data/2.60.40.420/                   6.119964e+00
# ../CATH_data/1.25.40.10/                    8.967551e+00
# ../CATH_data/3.30.200.20/                   5.076079e+00
# ../CATH_data/3.40.47.10/                    2.042850e+01
# ../CATH_data/2.40.10.10/                    3.318588e+00
# ../CATH_data/2.40.50.40/                    1.694642e+02
# ../CATH_data/3.90.190.10/                   2.287615e+00
# ../CATH_data/1.20.1050.10/                  7.671896e+01
# ../CATH_data/2.30.110.10/                   2.089196e+01
# ../CATH_data/3.40.50.150/                   3.300834e+01
# ../CATH_data/3.10.100.10/                   1.331430e+02
# ../CATH_data/3.60.15.10/                    1.560856e+01
# ../CATH_data/1.10.600.10/                   3.568958e+00
# ../CATH_data/3.40.50.300/                   2.472449e+01
# ../CATH_data/2.40.50.140/                   1.694497e+01
# ../CATH_data/3.30.530.20/                   6.644748e+01
# ../CATH_data/2.60.40.1180/                  9.905114e+00
# ../CATH_data/1.20.1260.10/                  1.945491e+01
# ../CATH_data/2.30.30.100/                   8.352176e+00
# ../CATH_data/3.20.20.140/                   2.724221e+01
# ../CATH_data/2.60.120.10/                   4.037913e+01
# ../CATH_data/3.10.450.50/                   3.860681e+01
# ../CATH_data/3.40.630.30/                   6.734024e+01
# ../CATH_data/2.30.30.40/                    5.090030e+04
# ../CATH_data/3.20.20.80/                    1.688326e+01
# ../CATH_data/3.20.20.120/                   2.838520e+01
# ../CATH_data/1.20.5.170/                    4.060342e+00
# ../CATH_data/1.10.760.10/                   1.791168e+01
# ../CATH_data/3.50.50.60/                    3.056764e+01
# ../CATH_data/2.60.120.200/                  4.419134e+01
# ../CATH_data/3.40.50.360/                   3.414652e+01
# ../CATH_data/3.40.50.1000/                  2.846087e+01
# ../CATH_data/3.90.550.10/                   1.266702e+01
# ../CATH_data/3.30.40.10/                    2.395860e+06
# ../CATH_data/3.80.10.10/                    2.660236e+00
# ../CATH_data/3.30.390.10/                   3.727537e+01
# ../CATH_data/3.40.50.970/                   8.078615e+00
# ../CATH_data/2.40.50.100/                   6.822403e+00
# ../CATH_data/1.10.630.10/                   2.567469e+01
# ../CATH_data/3.40.640.10/                   3.024716e+01
# ../CATH_data/3.90.79.10/                    2.451304e+01
# ../CATH_data/1.10.533.10/                  -9.422003e+03
# ../CATH_data/3.90.226.10/                   1.565925e+01
# ../CATH_data/3.30.450.40/                   6.946529e+00
# ../CATH_data/3.40.50.1820/                  4.103287e+01
# ../CATH_data/1.10.238.10/                   2.586997e+01
#
#                             alntmscore_0_exp_struct_tree  \
# ../CATH_data/1.10.490.10/                      86.070689
# ../CATH_data/3.40.1190.20/                     14.410013
# ../CATH_data/3.40.30.10/                       30.575555
# ../CATH_data/3.40.50.720/                      63.663342
# ../CATH_data/3.20.20.70/                       31.542715
# ../CATH_data/3.90.180.10/                      33.216726
# ../CATH_data/3.10.20.90/                       11.850864
# ../CATH_data/3.40.50.880/                      16.133585
# ../CATH_data/3.30.70.100/                      26.406621
# ../CATH_data/1.10.8.60/                         9.648652
# ../CATH_data/2.30.42.10/                        7.352582
# ../CATH_data/3.30.360.10/                      21.254092
# ../CATH_data/2.80.10.50/                       21.546411
# ../CATH_data/3.30.450.20/                       5.529481
# ../CATH_data/2.60.40.420/                       6.355632
# ../CATH_data/1.25.40.10/                        6.616434
# ../CATH_data/3.30.200.20/                       3.453347
# ../CATH_data/3.40.47.10/                       19.508474
# ../CATH_data/2.40.10.10/                        2.853117
# ../CATH_data/2.40.50.40/                      136.909161
# ../CATH_data/3.90.190.10/                       2.248357
# ../CATH_data/1.20.1050.10/                    101.710364
# ../CATH_data/2.30.110.10/                      15.721060
# ../CATH_data/3.40.50.150/                      27.253209
# ../CATH_data/3.10.100.10/                     124.642553
# ../CATH_data/3.60.15.10/                       12.957955
# ../CATH_data/1.10.600.10/                       1.623852
# ../CATH_data/3.40.50.300/                      18.359486
# ../CATH_data/2.40.50.140/                      13.741028
# ../CATH_data/3.30.530.20/                      49.727779
# ../CATH_data/2.60.40.1180/                     12.257807
# ../CATH_data/1.20.1260.10/                     14.361898
# ../CATH_data/2.30.30.100/                       8.107404
# ../CATH_data/3.20.20.140/                      22.600471
# ../CATH_data/2.60.120.10/                      33.220218
# ../CATH_data/3.10.450.50/                      36.830039
# ../CATH_data/3.40.630.30/                      58.458558
# ../CATH_data/2.30.30.40/                      732.143817
# ../CATH_data/3.20.20.80/                       14.403784
# ../CATH_data/3.20.20.120/                      26.676436
# ../CATH_data/1.20.5.170/                        3.583547
# ../CATH_data/1.10.760.10/                      20.680735
# ../CATH_data/3.50.50.60/                       24.359075
# ../CATH_data/2.60.120.200/                     29.878996
# ../CATH_data/3.40.50.360/                      31.667297
# ../CATH_data/3.40.50.1000/                     25.390165
# ../CATH_data/3.90.550.10/                       9.292563
# ../CATH_data/3.30.40.10/                      938.322606
# ../CATH_data/3.80.10.10/                        2.703675
# ../CATH_data/3.30.390.10/                      33.012831
# ../CATH_data/3.40.50.970/                       7.829002
# ../CATH_data/2.40.50.100/                       5.125135
# ../CATH_data/1.10.630.10/                      23.291098
# ../CATH_data/3.40.640.10/                      33.511923
# ../CATH_data/3.90.79.10/                       22.543235
# ../CATH_data/1.10.533.10/                     494.780453
# ../CATH_data/3.90.226.10/                      15.043027
# ../CATH_data/3.30.450.40/                       5.949074
# ../CATH_data/3.40.50.1820/                     38.532340
# ../CATH_data/1.10.238.10/                      22.985593
#
#                             alntmscore_1_exp_struct_tree  \
# ../CATH_data/1.10.490.10/                      41.640244
# ../CATH_data/3.40.1190.20/                     16.088598
# ../CATH_data/3.40.30.10/                       33.438482
# ../CATH_data/3.40.50.720/                      57.318020
# ../CATH_data/3.20.20.70/                       40.701154
# ../CATH_data/3.90.180.10/                      32.341839
# ../CATH_data/3.10.20.90/                        4.226513
# ../CATH_data/3.40.50.880/                      15.447032
# ../CATH_data/3.30.70.100/                      24.245041
# ../CATH_data/1.10.8.60/                         5.255402
# ../CATH_data/2.30.42.10/                        8.439346
# ../CATH_data/3.30.360.10/                      18.870047
# ../CATH_data/2.80.10.50/                       17.568080
# ../CATH_data/3.30.450.20/                       4.102146
# ../CATH_data/2.60.40.420/                       5.785898
# ../CATH_data/1.25.40.10/                       13.510751
# ../CATH_data/3.30.200.20/                       4.029683
# ../CATH_data/3.40.47.10/                       19.649177
# ../CATH_data/2.40.10.10/                             NaN
# ../CATH_data/2.40.50.40/                      156.048597
# ../CATH_data/3.90.190.10/                       1.951143
# ../CATH_data/1.20.1050.10/                    100.133486
# ../CATH_data/2.30.110.10/                      16.775613
# ../CATH_data/3.40.50.150/                      32.578757
# ../CATH_data/3.10.100.10/                     117.568902
# ../CATH_data/3.60.15.10/                       13.316516
# ../CATH_data/1.10.600.10/                       6.305963
# ../CATH_data/3.40.50.300/                      18.272385
# ../CATH_data/2.40.50.140/                      12.855625
# ../CATH_data/3.30.530.20/                      62.795779
# ../CATH_data/2.60.40.1180/                     11.278695
# ../CATH_data/1.20.1260.10/                     18.247944
# ../CATH_data/2.30.30.100/                       6.006513
# ../CATH_data/3.20.20.140/                      30.085095
# ../CATH_data/2.60.120.10/                      27.218629
# ../CATH_data/3.10.450.50/                      38.368954
# ../CATH_data/3.40.630.30/                      60.484615
# ../CATH_data/2.30.30.40/                     1008.730363
# ../CATH_data/3.20.20.80/                       13.391196
# ../CATH_data/3.20.20.120/                      26.619376
# ../CATH_data/1.20.5.170/                        3.997865
# ../CATH_data/1.10.760.10/                       8.848510
# ../CATH_data/3.50.50.60/                       25.799097
# ../CATH_data/2.60.120.200/                     68.584438
# ../CATH_data/3.40.50.360/                      31.194958
# ../CATH_data/3.40.50.1000/                     23.235822
# ../CATH_data/3.90.550.10/                      10.146550
# ../CATH_data/3.30.40.10/                     1304.669246
# ../CATH_data/3.80.10.10/                        2.153670
# ../CATH_data/3.30.390.10/                      32.605916
# ../CATH_data/3.40.50.970/                       7.403513
# ../CATH_data/2.40.50.100/                       4.735372
# ../CATH_data/1.10.630.10/                      41.981758
# ../CATH_data/3.40.640.10/                      31.883921
# ../CATH_data/3.90.79.10/                       23.328572
# ../CATH_data/1.10.533.10/                     667.315293
# ../CATH_data/3.90.226.10/                      14.078620
# ../CATH_data/3.30.450.40/                       6.408779
# ../CATH_data/3.40.50.1820/                     30.282523
# ../CATH_data/1.10.238.10/                      24.013434
#
#                             fident_0_raw_struct_tree  lddt_0_exp_struct_tree  \
# ../CATH_data/1.10.490.10/               2.918470e+02               40.690750
# ../CATH_data/3.40.1190.20/              4.585337e+01               21.333855
# ../CATH_data/3.40.30.10/                1.645863e+02               52.428613
# ../CATH_data/3.40.50.720/               1.715130e+02               82.961087
# ../CATH_data/3.20.20.70/                1.007971e+02               47.190589
# ../CATH_data/3.90.180.10/               8.904266e+01               42.745304
# ../CATH_data/3.10.20.90/                1.528086e+01                7.458915
# ../CATH_data/3.40.50.880/               4.326336e+01               20.455206
# ../CATH_data/3.30.70.100/               5.899331e+01               29.457253
# ../CATH_data/1.10.8.60/                 7.754348e+00                4.658021
# ../CATH_data/2.30.42.10/                9.008435e+00                5.223559
# ../CATH_data/3.30.360.10/               8.753937e+01               33.479489
# ../CATH_data/2.80.10.50/                4.588548e+01               25.779771
# ../CATH_data/3.30.450.20/               1.056717e+01                6.371315
# ../CATH_data/2.60.40.420/               1.572249e+01                6.171684
# ../CATH_data/1.25.40.10/                1.231866e+01                8.196770
# ../CATH_data/3.30.200.20/               8.120136e+00                5.176788
# ../CATH_data/3.40.47.10/                7.251469e+01               25.992588
# ../CATH_data/2.40.10.10/                8.404665e+00                4.759436
# ../CATH_data/2.40.50.40/                1.172264e+02               56.307071
# ../CATH_data/3.90.190.10/               2.374854e+01                2.663822
# ../CATH_data/1.20.1050.10/              2.918110e+02              115.678274
# ../CATH_data/2.30.110.10/               4.252735e+01               23.150033
# ../CATH_data/3.40.50.150/               7.057141e+01               40.322843
# ../CATH_data/3.10.100.10/               1.814913e+02               96.052967
# ../CATH_data/3.60.15.10/                3.110459e+01               17.441775
# ../CATH_data/1.10.600.10/               8.004289e+00                2.207894
# ../CATH_data/3.40.50.300/               5.146404e+01               25.511438
# ../CATH_data/2.40.50.140/               2.954142e+01               14.737488
# ../CATH_data/3.30.530.20/               1.534065e+02               79.520316
# ../CATH_data/2.60.40.1180/              2.547440e+01                9.016527
# ../CATH_data/1.20.1260.10/              3.909210e+01               18.214482
# ../CATH_data/2.30.30.100/               1.548667e+01                6.923643
# ../CATH_data/3.20.20.140/               6.564561e+01               33.274663
# ../CATH_data/2.60.120.10/               8.526563e+01               43.795677
# ../CATH_data/3.10.450.50/               6.983224e+01               42.190958
# ../CATH_data/3.40.630.30/               1.179875e+02               81.049305
# ../CATH_data/2.30.30.40/               -2.405992e+09              819.318662
# ../CATH_data/3.20.20.80/                3.207292e+01               18.904041
# ../CATH_data/3.20.20.120/               1.062213e+02               43.058812
# ../CATH_data/1.20.5.170/                4.735895e+00                4.097438
# ../CATH_data/1.10.760.10/               3.405522e+01               14.258434
# ../CATH_data/3.50.50.60/                7.231185e+01               37.493533
# ../CATH_data/2.60.120.200/              1.246200e+02               49.878012
# ../CATH_data/3.40.50.360/               8.779729e+01               46.087477
# ../CATH_data/3.40.50.1000/              7.398734e+01               37.969736
# ../CATH_data/3.90.550.10/               3.223385e+01               18.593074
# ../CATH_data/3.30.40.10/                1.622974e+05             1123.433843
# ../CATH_data/3.80.10.10/                1.925190e+01                3.643497
# ../CATH_data/3.30.390.10/               1.278896e+02               60.914788
# ../CATH_data/3.40.50.970/               2.076537e+01               10.937588
# ../CATH_data/2.40.50.100/               2.397783e+01                8.771431
# ../CATH_data/1.10.630.10/               1.024217e+02               70.733772
# ../CATH_data/3.40.640.10/               9.824007e+01               50.625968
# ../CATH_data/3.90.79.10/                4.314461e+01               27.948027
# ../CATH_data/1.10.533.10/              -2.389069e+05              600.364233
# ../CATH_data/3.90.226.10/               4.938063e+01               20.818493
# ../CATH_data/3.30.450.40/               1.067599e+01                7.409174
# ../CATH_data/3.40.50.1820/              8.621051e+01               30.715431
# ../CATH_data/1.10.238.10/               7.860019e+01               34.974773
#
#                             lddt_1_exp_struct_tree  fident_0_exp_struct_tree  \
# ../CATH_data/1.10.490.10/                59.171733                231.505211
# ../CATH_data/3.40.1190.20/               20.394858                 35.213446
# ../CATH_data/3.40.30.10/                 45.896692                117.724569
# ../CATH_data/3.40.50.720/                76.571960                152.532040
# ../CATH_data/3.20.20.70/                 55.014947                 80.401492
# ../CATH_data/3.90.180.10/                33.703354                 74.797596
# ../CATH_data/3.10.20.90/                  4.571727                 12.108237
# ../CATH_data/3.40.50.880/                20.074924                 35.047855
# ../CATH_data/3.30.70.100/                29.727802                 51.240232
# ../CATH_data/1.10.8.60/                   5.949304                  6.146849
# ../CATH_data/2.30.42.10/                  4.412324                  7.946498
# ../CATH_data/3.30.360.10/                32.119946                 65.580504
# ../CATH_data/2.80.10.50/                 26.494413                 46.002920
# ../CATH_data/3.30.450.20/                 6.232581                  8.514517
# ../CATH_data/2.60.40.420/                 6.005596                 11.195416
# ../CATH_data/1.25.40.10/                  9.852541                 11.143993
# ../CATH_data/3.30.200.20/                 5.183492                  7.081116
# ../CATH_data/3.40.47.10/                 27.421761                 50.920755
# ../CATH_data/2.40.10.10/                  4.683785                  6.481294
# ../CATH_data/2.40.50.40/                 67.128898                 88.702844
# ../CATH_data/3.90.190.10/                 2.359985                 23.329766
# ../CATH_data/1.20.1050.10/              143.594952                222.557535
# ../CATH_data/2.30.110.10/                27.423235                 35.113175
# ../CATH_data/3.40.50.150/                35.927321                 55.329285
# ../CATH_data/3.10.100.10/               129.400083                150.043411
# ../CATH_data/3.60.15.10/                 17.950033                 26.298544
# ../CATH_data/1.10.600.10/                 6.891079                  2.661029
# ../CATH_data/3.40.50.300/                20.129175                 42.305188
# ../CATH_data/2.40.50.140/                16.008324                 22.607404
# ../CATH_data/3.30.530.20/                73.443342                112.085282
# ../CATH_data/2.60.40.1180/               14.180346                 19.987510
# ../CATH_data/1.20.1260.10/               19.683765                 33.634062
# ../CATH_data/2.30.30.100/                 7.490471                 12.763836
# ../CATH_data/3.20.20.140/                33.319590                 53.574147
# ../CATH_data/2.60.120.10/                43.853838                 68.985708
# ../CATH_data/3.10.450.50/                44.495765                 55.503157
# ../CATH_data/3.40.630.30/                61.822353                 88.322053
# ../CATH_data/2.30.30.40/               1155.846801                778.399118
# ../CATH_data/3.20.20.80/                 16.697507                 26.622221
# ../CATH_data/3.20.20.120/                44.361806                 83.680275
# ../CATH_data/1.20.5.170/                  3.830187                  5.270374
# ../CATH_data/1.10.760.10/                17.893579                 23.880702
# ../CATH_data/3.50.50.60/                 38.742640                 57.429406
# ../CATH_data/2.60.120.200/               52.173125                 95.026598
# ../CATH_data/3.40.50.360/                45.955131                 68.316985
# ../CATH_data/3.40.50.1000/               34.848226                 58.915918
# ../CATH_data/3.90.550.10/                17.496008                 26.081906
# ../CATH_data/3.30.40.10/               1113.273845               1061.309508
# ../CATH_data/3.80.10.10/                  3.644801                 13.318417
# ../CATH_data/3.30.390.10/                59.425052                 97.093439
# ../CATH_data/3.40.50.970/                12.093765                 16.469853
# ../CATH_data/2.40.50.100/                 7.569976                 19.237047
# ../CATH_data/1.10.630.10/                70.571118                 87.570720
# ../CATH_data/3.40.640.10/                48.577989                 74.187897
# ../CATH_data/3.90.79.10/                 27.269194                 36.847285
# ../CATH_data/1.10.533.10/               574.218214                602.072995
# ../CATH_data/3.90.226.10/                23.595278                 39.236176
# ../CATH_data/3.30.450.40/                 8.261650                  8.828556
# ../CATH_data/3.40.50.1820/               54.501339                 69.360217
# ../CATH_data/1.10.238.10/                39.939811                 58.821780
#
#                             lddt_1_raw_struct_tree  fident_1_raw_struct_tree  \
# ../CATH_data/1.10.490.10/                69.860677                318.375631
# ../CATH_data/3.40.1190.20/               27.307396                 56.106822
# ../CATH_data/3.40.30.10/                 71.543832                256.760541
# ../CATH_data/3.40.50.720/                98.621869                225.611672
# ../CATH_data/3.20.20.70/                       NaN                132.042436
# ../CATH_data/3.90.180.10/                41.513697                114.060553
# ../CATH_data/3.10.20.90/                  5.416524                  9.756304
# ../CATH_data/3.40.50.880/                26.514573                 50.876861
# ../CATH_data/3.30.70.100/                38.480708                 89.165846
# ../CATH_data/1.10.8.60/                   7.969697                 15.454287
# ../CATH_data/2.30.42.10/                  5.072580                  8.047750
# ../CATH_data/3.30.360.10/                43.097055                112.113868
# ../CATH_data/2.80.10.50/                 33.688119                 45.857073
# ../CATH_data/3.30.450.20/                 6.579588                 10.167650
# ../CATH_data/2.60.40.420/                 7.619830                 21.321033
# ../CATH_data/1.25.40.10/                  9.650846                 20.384932
# ../CATH_data/3.30.200.20/                 6.257427                  7.375568
# ../CATH_data/3.40.47.10/                 34.250173                 96.715607
# ../CATH_data/2.40.10.10/                  5.773266                 10.702646
# ../CATH_data/2.40.50.40/                 88.641319                212.424473
# ../CATH_data/3.90.190.10/                 2.469856                  3.645509
# ../CATH_data/1.20.1050.10/              135.458553                411.042112
# ../CATH_data/2.30.110.10/                32.242177                 58.631515
# ../CATH_data/3.40.50.150/                45.890942                 82.966151
# ../CATH_data/3.10.100.10/               137.800169                211.698560
# ../CATH_data/3.60.15.10/                 22.290782                 39.899194
# ../CATH_data/1.10.600.10/                 8.213279                 15.646336
# ../CATH_data/3.40.50.300/                29.827727                 65.134273
# ../CATH_data/2.40.50.140/                18.382558                 36.556553
# ../CATH_data/3.30.530.20/                72.509961                180.600802
# ../CATH_data/2.60.40.1180/               19.930120                 40.287050
# ../CATH_data/1.20.1260.10/               22.647127                 69.115383
# ../CATH_data/2.30.30.100/                 8.084916                 15.666126
# ../CATH_data/3.20.20.140/                43.517370                 76.461445
# ../CATH_data/2.60.120.10/                54.042189                 94.072619
# ../CATH_data/3.10.450.50/                50.151090                 87.088131
# ../CATH_data/3.40.630.30/                83.594705                167.035726
# ../CATH_data/2.30.30.40/               1079.380344            -134057.875341
# ../CATH_data/3.20.20.80/                 19.331094                 41.064471
# ../CATH_data/3.20.20.120/                53.990029                118.710381
# ../CATH_data/1.20.5.170/                  4.141432                  5.402883
# ../CATH_data/1.10.760.10/                      NaN                 47.040779
# ../CATH_data/3.50.50.60/                 53.032222                 99.381461
# ../CATH_data/2.60.120.200/               61.421935                142.848771
# ../CATH_data/3.40.50.360/                53.877119                116.946654
# ../CATH_data/3.40.50.1000/               44.173281                106.100412
# ../CATH_data/3.90.550.10/                21.879367                 39.577802
# ../CATH_data/3.30.40.10/             124254.550154              29046.507712
# ../CATH_data/3.80.10.10/                  4.750982                 23.957208
# ../CATH_data/3.30.390.10/                74.652199                158.457876
# ../CATH_data/3.40.50.970/                15.338926                 26.186823
# ../CATH_data/2.40.50.100/                12.976016                 29.520878
# ../CATH_data/1.10.630.10/                78.576992                111.269540
# ../CATH_data/3.40.640.10/                58.791060                129.173448
# ../CATH_data/3.90.79.10/                 30.942282                 50.312256
# ../CATH_data/1.10.533.10/               988.178119              10543.161502
# ../CATH_data/3.90.226.10/                29.541378                 69.659941
# ../CATH_data/3.30.450.40/                 9.260132                  9.522808
# ../CATH_data/3.40.50.1820/               48.653398                 96.220415
# ../CATH_data/1.10.238.10/                25.147442                 97.923346
#
#                             fident_1_exp_struct_tree  ...  \
# ../CATH_data/1.10.490.10/                 185.778585  ...
# ../CATH_data/3.40.1190.20/                 37.673544  ...
# ../CATH_data/3.40.30.10/                  153.083165  ...
# ../CATH_data/3.40.50.720/                 154.850611  ...
# ../CATH_data/3.20.20.70/                   92.061196  ...
# ../CATH_data/3.90.180.10/                  77.810100  ...
# ../CATH_data/3.10.20.90/                    7.531285  ...
# ../CATH_data/3.40.50.880/                  37.777500  ...
# ../CATH_data/3.30.70.100/                  67.260759  ...
# ../CATH_data/1.10.8.60/                    11.903990  ...
# ../CATH_data/2.30.42.10/                    6.204016  ...
# ../CATH_data/3.30.360.10/                  73.800521  ...
# ../CATH_data/2.80.10.50/                   35.367803  ...
# ../CATH_data/3.30.450.20/                   8.774980  ...
# ../CATH_data/2.60.40.420/                  11.577954  ...
# ../CATH_data/1.25.40.10/                   17.705746  ...
# ../CATH_data/3.30.200.20/                   5.813869  ...
# ../CATH_data/3.40.47.10/                   57.497766  ...
# ../CATH_data/2.40.10.10/                    7.929830  ...
# ../CATH_data/2.40.50.40/                  135.835294  ...
# ../CATH_data/3.90.190.10/                   3.327261  ...
# ../CATH_data/1.20.1050.10/                266.141232  ...
# ../CATH_data/2.30.110.10/                  40.842642  ...
# ../CATH_data/3.40.50.150/                  56.186234  ...
# ../CATH_data/3.10.100.10/                 141.709722  ...
# ../CATH_data/3.60.15.10/                   32.923820  ...
# ../CATH_data/1.10.600.10/                  11.208234  ...
# ../CATH_data/3.40.50.300/                  36.809289  ...
# ../CATH_data/2.40.50.140/                  25.516268  ...
# ../CATH_data/3.30.530.20/                  99.594744  ...
# ../CATH_data/2.60.40.1180/                 22.791576  ...
# ../CATH_data/1.20.1260.10/                 48.493781  ...
# ../CATH_data/2.30.30.100/                  11.424601  ...
# ../CATH_data/3.20.20.140/                  59.062523  ...
# ../CATH_data/2.60.120.10/                  68.647787  ...
# ../CATH_data/3.10.450.50/                  65.587885  ...
# ../CATH_data/3.40.630.30/                 130.187603  ...
# ../CATH_data/2.30.30.40/                 1325.706634  ...
# ../CATH_data/3.20.20.80/                   30.645770  ...
# ../CATH_data/3.20.20.120/                  71.442323  ...
# ../CATH_data/1.20.5.170/                    4.640250  ...
# ../CATH_data/1.10.760.10/                  33.405440  ...
# ../CATH_data/3.50.50.60/                   75.153132  ...
# ../CATH_data/2.60.120.200/                 87.104269  ...
# ../CATH_data/3.40.50.360/                  77.708216  ...
# ../CATH_data/3.40.50.1000/                 79.094512  ...
# ../CATH_data/3.90.550.10/                  27.065900  ...
# ../CATH_data/3.30.40.10/                 1170.603074  ...
# ../CATH_data/3.80.10.10/                   14.711424  ...
# ../CATH_data/3.30.390.10/                 109.575345  ...
# ../CATH_data/3.40.50.970/                  22.979588  ...
# ../CATH_data/2.40.50.100/                  18.114307  ...
# ../CATH_data/1.10.630.10/                  95.488523  ...
# ../CATH_data/3.40.640.10/                  89.158397  ...
# ../CATH_data/3.90.79.10/                   42.987188  ...
# ../CATH_data/1.10.533.10/                 660.026224  ...
# ../CATH_data/3.90.226.10/                  48.026601  ...
# ../CATH_data/3.30.450.40/                   7.430430  ...
# ../CATH_data/3.40.50.1820/                 67.910751  ...
# ../CATH_data/1.10.238.10/                  60.266856  ...
#
#                             alntmscore_1_raw_struct_tree_lddt_0_raw_struct_tree_max  \
# ../CATH_data/1.10.490.10/                                           66.387465
# ../CATH_data/3.40.1190.20/                                          29.498136
# ../CATH_data/3.40.30.10/                                            77.094644
# ../CATH_data/3.40.50.720/                                          108.878877
# ../CATH_data/3.20.20.70/                                            42.528105
# ../CATH_data/3.90.180.10/                                           49.384662
# ../CATH_data/3.10.20.90/                                             6.265775
# ../CATH_data/3.40.50.880/                                           26.509760
# ../CATH_data/3.30.70.100/                                           35.758728
# ../CATH_data/1.10.8.60/                                              8.639817
# ../CATH_data/2.30.42.10/                                             9.442772
# ../CATH_data/3.30.360.10/                                           44.799217
# ../CATH_data/2.80.10.50/                                            33.049342
# ../CATH_data/3.30.450.20/                                            6.686962
# ../CATH_data/2.60.40.420/                                            7.624644
# ../CATH_data/1.25.40.10/                                             9.278422
# ../CATH_data/3.30.200.20/                                            6.261398
# ../CATH_data/3.40.47.10/                                            36.088790
# ../CATH_data/2.40.10.10/                                                  NaN
# ../CATH_data/2.40.50.40/                                           183.167591
# ../CATH_data/3.90.190.10/                                            2.715252
# ../CATH_data/1.20.1050.10/                                         143.677718
# ../CATH_data/2.30.110.10/                                           30.204093
# ../CATH_data/3.40.50.150/                                           46.165422
# ../CATH_data/3.10.100.10/                                          139.890037
# ../CATH_data/3.60.15.10/                                            21.312328
# ../CATH_data/1.10.600.10/                                            6.031028
# ../CATH_data/3.40.50.300/                                           32.333046
# ../CATH_data/2.40.50.140/                                           19.894413
# ../CATH_data/3.30.530.20/                                           92.177879
# ../CATH_data/2.60.40.1180/                                          13.852226
# ../CATH_data/1.20.1260.10/                                          26.850114
# ../CATH_data/2.30.30.100/                                            7.947120
# ../CATH_data/3.20.20.140/                                           42.795559
# ../CATH_data/2.60.120.10/                                           48.808974
# ../CATH_data/3.10.450.50/                                           45.646073
# ../CATH_data/3.40.630.30/                                           87.013177
# ../CATH_data/2.30.30.40/                                          2816.594494
# ../CATH_data/3.20.20.80/                                            22.711602
# ../CATH_data/3.20.20.120/                                           52.433619
# ../CATH_data/1.20.5.170/                                             4.324001
# ../CATH_data/1.10.760.10/                                           12.313341
# ../CATH_data/3.50.50.60/                                            48.336312
# ../CATH_data/2.60.120.200/                                          66.935841
# ../CATH_data/3.40.50.360/                                           56.441788
# ../CATH_data/3.40.50.1000/                                          46.813300
# ../CATH_data/3.90.550.10/                                           23.711739
# ../CATH_data/3.30.40.10/                                          7024.692135
# ../CATH_data/3.80.10.10/                                             4.815950
# ../CATH_data/3.30.390.10/                                           69.998629
# ../CATH_data/3.40.50.970/                                           13.702281
# ../CATH_data/2.40.50.100/                                           12.558139
# ../CATH_data/1.10.630.10/                                           78.453766
# ../CATH_data/3.40.640.10/                                           61.110474
# ../CATH_data/3.90.79.10/                                            31.378825
# ../CATH_data/1.10.533.10/                                         7097.709437
# ../CATH_data/3.90.226.10/                                           29.681178
# ../CATH_data/3.30.450.40/                                            8.587125
# ../CATH_data/3.40.50.1820/                                          46.652089
# ../CATH_data/1.10.238.10/                                           27.176508
#
#                             alntmscore_1_raw_struct_tree_lddt_0_raw_struct_tree_delta_norm  \
# ../CATH_data/1.10.490.10/                                           -0.373019
# ../CATH_data/3.40.1190.20/                                          -0.433838
# ../CATH_data/3.40.30.10/                                            -0.444660
# ../CATH_data/3.40.50.720/                                           -0.293438
# ../CATH_data/3.20.20.70/                                                  NaN
# ../CATH_data/3.90.180.10/                                           -0.345789
# ../CATH_data/3.10.20.90/                                             0.268487
# ../CATH_data/3.40.50.880/                                           -0.300289
# ../CATH_data/3.30.70.100/                                           -0.157442
# ../CATH_data/1.10.8.60/                                             -0.131287
# ../CATH_data/2.30.42.10/                                             0.427153
# ../CATH_data/3.30.360.10/                                           -0.404246
# ../CATH_data/2.80.10.50/                                            -0.142039
# ../CATH_data/3.30.450.20/                                           -0.270060
# ../CATH_data/2.60.40.420/                                           -0.136213
# ../CATH_data/1.25.40.10/                                             0.041625
# ../CATH_data/3.30.200.20/                                           -0.218850
# ../CATH_data/3.40.47.10/                                            -0.375776
# ../CATH_data/2.40.10.10/                                                  NaN
# ../CATH_data/2.40.50.40/                                             0.573514
# ../CATH_data/3.90.190.10/                                           -0.260206
# ../CATH_data/1.20.1050.10/                                          -0.233837
# ../CATH_data/2.30.110.10/                                           -0.304963
# ../CATH_data/3.40.50.150/                                           -0.162686
# ../CATH_data/3.10.100.10/                                           -0.089766
# ../CATH_data/3.60.15.10/                                            -0.265237
# ../CATH_data/1.10.600.10/                                           -0.097516
# ../CATH_data/3.40.50.300/                                           -0.160797
# ../CATH_data/2.40.50.140/                                           -0.268502
# ../CATH_data/3.30.530.20/                                           -0.276099
# ../CATH_data/2.60.40.1180/                                          -0.369332
# ../CATH_data/1.20.1260.10/                                          -0.401702
# ../CATH_data/2.30.30.100/                                           -0.125019
# ../CATH_data/3.20.20.140/                                           -0.244994
# ../CATH_data/2.60.120.10/                                           -0.287507
# ../CATH_data/3.10.450.50/                                           -0.072320
# ../CATH_data/3.40.630.30/                                           -0.207026
# ../CATH_data/2.30.30.40/                                           130.725548
# ../CATH_data/3.20.20.80/                                            -0.350919
# ../CATH_data/3.20.20.120/                                           -0.462216
# ../CATH_data/1.20.5.170/                                             0.005963
# ../CATH_data/1.10.760.10/                                                 NaN
# ../CATH_data/3.50.50.60/                                            -0.328113
# ../CATH_data/2.60.120.200/                                          -0.129802
# ../CATH_data/3.40.50.360/                                           -0.393021
# ../CATH_data/3.40.50.1000/                                          -0.320231
# ../CATH_data/3.90.550.10/                                           -0.463654
# ../CATH_data/3.30.40.10/                                             0.660101
# ../CATH_data/3.80.10.10/                                            -0.472123
# ../CATH_data/3.30.390.10/                                           -0.451876
# ../CATH_data/3.40.50.970/                                           -0.415973
# ../CATH_data/2.40.50.100/                                           -0.474132
# ../CATH_data/1.10.630.10/                                           -0.418276
# ../CATH_data/3.40.640.10/                                           -0.500730
# ../CATH_data/3.90.79.10/                                            -0.180239
# ../CATH_data/1.10.533.10/                                           -0.932675
# ../CATH_data/3.90.226.10/                                           -0.430392
# ../CATH_data/3.30.450.40/                                           -0.130958
# ../CATH_data/3.40.50.1820/                                          -0.208449
# ../CATH_data/1.10.238.10/                                            0.060448
#
#                             alntmscore_1_raw_struct_tree_sequences_delta  \
# ../CATH_data/1.10.490.10/                                    -991.184865
# ../CATH_data/3.40.1190.20/                                    -56.698261
# ../CATH_data/3.40.30.10/                                     -405.653239
# ../CATH_data/3.40.50.720/                                    -290.055179
# ../CATH_data/3.20.20.70/                                     -154.072755
# ../CATH_data/3.90.180.10/                                    -247.162189
# ../CATH_data/3.10.20.90/                                      -91.079505
# ../CATH_data/3.40.50.880/                                     -40.077205
# ../CATH_data/3.30.70.100/                                     -51.822893
# ../CATH_data/1.10.8.60/                                        -0.170938
# ../CATH_data/2.30.42.10/                                       -3.610191
# ../CATH_data/3.30.360.10/                                    -254.786053
# ../CATH_data/2.80.10.50/                                      -53.303028
# ../CATH_data/3.30.450.20/                                     -22.018183
# ../CATH_data/2.60.40.420/                                     -33.014894
# ../CATH_data/1.25.40.10/                                        3.817387
# ../CATH_data/3.30.200.20/                                       0.295220
# ../CATH_data/3.40.47.10/                                     -188.090257
# ../CATH_data/2.40.10.10/                                             NaN
# ../CATH_data/2.40.50.40/                                       38.370431
# ../CATH_data/3.90.190.10/                                       1.226249
# ../CATH_data/1.20.1050.10/                                   -728.583225
# ../CATH_data/2.30.110.10/                                     -27.829279
# ../CATH_data/3.40.50.150/                                     -54.293473
# ../CATH_data/3.10.100.10/                                     -60.999128
# ../CATH_data/3.60.15.10/                                      -19.791672
# ../CATH_data/1.10.600.10/                                     -16.670406
# ../CATH_data/3.40.50.300/                                     -52.806914
# ../CATH_data/2.40.50.140/                                     -20.066335
# ../CATH_data/3.30.530.20/                                    -387.153202
# ../CATH_data/2.60.40.1180/                                    -26.346336
# ../CATH_data/1.20.1260.10/                                    -85.287872
# ../CATH_data/2.30.30.100/                                     -35.744450
# ../CATH_data/3.20.20.140/                                     -61.355890
# ../CATH_data/2.60.120.10/                                     -93.010569
# ../CATH_data/3.10.450.50/                                     -48.310459
# ../CATH_data/3.40.630.30/                                     -61.860903
# ../CATH_data/2.30.30.40/                                     1608.584628
# ../CATH_data/3.20.20.80/                                      -21.751016
# ../CATH_data/3.20.20.120/                                    -166.777763
# ../CATH_data/1.20.5.170/                                        3.164079
# ../CATH_data/1.10.760.10/                                    -124.245251
# ../CATH_data/3.50.50.60/                                      -73.840589
# ../CATH_data/2.60.120.200/                                   -321.736652
# ../CATH_data/3.40.50.360/                                    -163.351992
# ../CATH_data/3.40.50.1000/                                    -85.428908
# ../CATH_data/3.90.550.10/                                     -29.433627
# ../CATH_data/3.30.40.10/                                     5560.104627
# ../CATH_data/3.80.10.10/                                      -60.432344
# ../CATH_data/3.30.390.10/                                    -220.628054
# ../CATH_data/3.40.50.970/                                     -19.322625
# ../CATH_data/2.40.50.100/                                     -19.218133
# ../CATH_data/1.10.630.10/                                     -64.752413
# ../CATH_data/3.40.640.10/                                    -145.214876
# ../CATH_data/3.90.79.10/                                      -22.074537
# ../CATH_data/1.10.533.10/                                    -227.861126
# ../CATH_data/3.90.226.10/                                     -45.236405
# ../CATH_data/3.30.450.40/                                      -2.004620
# ../CATH_data/3.40.50.1820/                                    -62.272514
# ../CATH_data/1.10.238.10/                                    -161.759244
#
#                             alntmscore_1_raw_struct_tree_sequences_max  \
# ../CATH_data/1.10.490.10/                                  1032.808555
# ../CATH_data/3.40.1190.20/                                   73.398976
# ../CATH_data/3.40.30.10/                                    448.467010
# ../CATH_data/3.40.50.720/                                   366.984847
# ../CATH_data/3.20.20.70/                                    196.600860
# ../CATH_data/3.90.180.10/                                   279.470195
# ../CATH_data/3.10.20.90/                                     97.345280
# ../CATH_data/3.40.50.880/                                    58.626374
# ../CATH_data/3.30.70.100/                                    81.951694
# ../CATH_data/1.10.8.60/                                       7.676462
# ../CATH_data/2.30.42.10/                                     13.052963
# ../CATH_data/3.30.360.10/                                   281.475377
# ../CATH_data/2.80.10.50/                                     81.658074
# ../CATH_data/3.30.450.20/                                    26.899263
# ../CATH_data/2.60.40.420/                                    39.600965
# ../CATH_data/1.25.40.10/                                      9.278422
# ../CATH_data/3.30.200.20/                                     4.891093
# ../CATH_data/3.40.47.10/                                    210.617741
# ../CATH_data/2.40.10.10/                                           NaN
# ../CATH_data/2.40.50.40/                                    183.167591
# ../CATH_data/3.90.190.10/                                     2.008728
# ../CATH_data/1.20.1050.10/                                  838.663749
# ../CATH_data/2.30.110.10/                                    48.822248
# ../CATH_data/3.40.50.150/                                    92.948433
# ../CATH_data/3.10.100.10/                                   188.331780
# ../CATH_data/3.60.15.10/                                     35.451183
# ../CATH_data/1.10.600.10/                                    22.113313
# ../CATH_data/3.40.50.300/                                    79.940900
# ../CATH_data/2.40.50.140/                                    34.619056
# ../CATH_data/3.30.530.20/                                   453.880815
# ../CATH_data/2.60.40.1180/                                   35.082491
# ../CATH_data/1.20.1260.10/                                  101.352248
# ../CATH_data/2.30.30.100/                                    42.698026
# ../CATH_data/3.20.20.140/                                    93.666780
# ../CATH_data/2.60.120.10/                                   127.786616
# ../CATH_data/3.10.450.50/                                    90.655393
# ../CATH_data/3.40.630.30/                                   130.860079
# ../CATH_data/2.30.30.40/                                   2816.594494
# ../CATH_data/3.20.20.80/                                     36.492685
# ...
# ../CATH_data/1.10.490.10/                              -966.421090
# ../CATH_data/3.40.1190.20/                              -43.900841
# ../CATH_data/3.40.30.10/                               -371.372366
# ../CATH_data/3.40.50.720/                              -258.105970
# ../CATH_data/3.20.20.70/                                       NaN
# ../CATH_data/3.90.180.10/                              -230.085533
# ../CATH_data/3.10.20.90/                                -92.761784
# ../CATH_data/3.40.50.880/                               -32.116614
# ../CATH_data/3.30.70.100/                               -46.192967
# ../CATH_data/1.10.8.60/                                   0.963355
# ../CATH_data/2.30.42.10/                                 -7.643697
# ../CATH_data/3.30.360.10/                              -236.676160
# ../CATH_data/2.80.10.50/                                -48.608732
# ../CATH_data/3.30.450.20/                               -20.212301
# ../CATH_data/2.60.40.420/                               -31.976321
# ../CATH_data/1.25.40.10/                                  3.431171
# ../CATH_data/3.30.200.20/                                 1.665525
# ../CATH_data/3.40.47.10/                               -174.528951
# ../CATH_data/2.40.10.10/                                 -1.192253
# ../CATH_data/2.40.50.40/                                -66.678814
# ../CATH_data/3.90.190.10/                                 1.932774
# ../CATH_data/1.20.1050.10/                             -694.986031
# ../CATH_data/2.30.110.10/                               -18.618155
# ../CATH_data/3.40.50.150/                               -46.783011
# ../CATH_data/3.10.100.10/                               -48.441744
# ../CATH_data/3.60.15.10/                                -14.138855
# ../CATH_data/1.10.600.10/                               -16.082285
# ../CATH_data/3.40.50.300/                               -47.607854
# ../CATH_data/2.40.50.140/                               -14.724643
# ../CATH_data/3.30.530.20/                              -361.702936
# ../CATH_data/2.60.40.1180/                              -21.230264
# ../CATH_data/1.20.1260.10/                              -74.502134
# ../CATH_data/2.30.30.100/                               -34.750905
# ../CATH_data/3.20.20.140/                               -50.871220
# ../CATH_data/2.60.120.10/                               -78.977642
# ../CATH_data/3.10.450.50/                               -45.009319
# ../CATH_data/3.40.630.30/                               -43.846902
# ../CATH_data/2.30.30.40/                            -366592.272706
# ../CATH_data/3.20.20.80/                                -13.781084
# ../CATH_data/3.20.20.120/                              -142.542127
# ../CATH_data/1.20.5.170/                                  3.138296
# ../CATH_data/1.10.760.10/                                      NaN
# ../CATH_data/3.50.50.60/                                -57.980805
# ../CATH_data/2.60.120.200/                             -313.048217
# ../CATH_data/3.40.50.360/                              -141.169197
# ../CATH_data/3.40.50.1000/                              -70.437846
# ../CATH_data/3.90.550.10/                               -18.439581
# ../CATH_data/3.30.40.10/                                923.097351
# ../CATH_data/3.80.10.10/                                -58.158621
# ../CATH_data/3.30.390.10/                              -188.997336
# ../CATH_data/3.40.50.970/                               -13.622846
# ../CATH_data/2.40.50.100/                               -13.263914
# ../CATH_data/1.10.630.10/                               -31.937122
# ../CATH_data/3.40.640.10/                              -114.615029
# ../CATH_data/3.90.79.10/                                -16.418851
# ../CATH_data/1.10.533.10/                              6391.993747
# ../CATH_data/3.90.226.10/                               -32.461867
# ../CATH_data/3.30.450.40/                                -0.880063
# ../CATH_data/3.40.50.1820/                              -52.547922
# ../CATH_data/1.10.238.10/                              -163.402018
#
#                             lddt_0_raw_struct_tree_sequences_max  \
# ../CATH_data/1.10.490.10/                            1032.808555
# ../CATH_data/3.40.1190.20/                             73.398976
# ../CATH_data/3.40.30.10/                              448.467010
# ../CATH_data/3.40.50.720/                             366.984847
# ../CATH_data/3.20.20.70/                                     NaN
# ../CATH_data/3.90.180.10/                             279.470195
# ../CATH_data/3.10.20.90/                               97.345280
# ../CATH_data/3.40.50.880/                              58.626374
# ../CATH_data/3.30.70.100/                              81.951694
# ../CATH_data/1.10.8.60/                                 8.639817
# ../CATH_data/2.30.42.10/                               13.052963
# ../CATH_data/3.30.360.10/                             281.475377
# ../CATH_data/2.80.10.50/                               81.658074
# ../CATH_data/3.30.450.20/                              26.899263
# ../CATH_data/2.60.40.420/                              39.600965
# ../CATH_data/1.25.40.10/                                8.892206
# ../CATH_data/3.30.200.20/                               6.261398
# ../CATH_data/3.40.47.10/                              210.617741
# ../CATH_data/2.40.10.10/                                6.995307
# ../CATH_data/2.40.50.40/                              144.797160
# ../CATH_data/3.90.190.10/                               2.715252
# ../CATH_data/1.20.1050.10/                            838.663749
# ../CATH_data/2.30.110.10/                              48.822248
# ../CATH_data/3.40.50.150/                              92.948433
# ../CATH_data/3.10.100.10/                             188.331780
# ../CATH_data/3.60.15.10/                               35.451183
# ../CATH_data/1.10.600.10/                              22.113313
# ../CATH_data/3.40.50.300/                              79.940900
# ../CATH_data/2.40.50.140/                              34.619056
# ../CATH_data/3.30.530.20/                             453.880815
# ../CATH_data/2.60.40.1180/                             35.082491
# ../CATH_data/1.20.1260.10/                            101.352248
# ../CATH_data/2.30.30.100/                              42.698026
# ../CATH_data/3.20.20.140/                              93.666780
# ../CATH_data/2.60.120.10/                             127.786616
# ../CATH_data/3.10.450.50/                              90.655393
# ../CATH_data/3.40.630.30/                             130.860079
# ../CATH_data/2.30.30.40/                             1208.009865
# ../CATH_data/3.20.20.80/                               36.492685
# ../CATH_data/3.20.20.120/                             194.975746
# ../CATH_data/1.20.5.170/                                4.298219
# ../CATH_data/1.10.760.10/                                    NaN
# ../CATH_data/3.50.50.60/                              106.317117
# ../CATH_data/2.60.120.200/                            379.984058
# ../CATH_data/3.40.50.360/                             197.610985
# ../CATH_data/3.40.50.1000/                            117.251146
# ../CATH_data/3.90.550.10/                              42.151320
# ../CATH_data/3.30.40.10/                             2387.684860
# ../CATH_data/3.80.10.10/                               62.974571
# ../CATH_data/3.30.390.10/                             258.995964
# ../CATH_data/3.40.50.970/                              27.325127
# ../CATH_data/2.40.50.100/                              25.822053
# ../CATH_data/1.10.630.10/                             110.390889
# ../CATH_data/3.40.640.10/                             175.725503
# ../CATH_data/3.90.79.10/                               47.797677
# ../CATH_data/1.10.533.10/                            7097.709437
# ../CATH_data/3.90.226.10/                              62.143044
# ../CATH_data/3.30.450.40/                               9.467188
# ../CATH_data/3.40.50.1820/                             99.200011
# ../CATH_data/1.10.238.10/                             188.935752
#
#                             lddt_0_raw_struct_tree_sequences_delta_norm  \
# ../CATH_data/1.10.490.10/                                     -0.935721
# ../CATH_data/3.40.1190.20/                                    -0.598112
# ../CATH_data/3.40.30.10/                                      -0.828093
# ../CATH_data/3.40.50.720/                                     -0.703315
# ../CATH_data/3.20.20.70/                                            NaN
# ../CATH_data/3.90.180.10/                                     -0.823292
# ../CATH_data/3.10.20.90/                                      -0.952915
# ../CATH_data/3.40.50.880/                                     -0.547819
# ../CATH_data/3.30.70.100/                                     -0.563661
# ../CATH_data/1.10.8.60/                                        0.111502
# ../CATH_data/2.30.42.10/                                      -0.585591
# ../CATH_data/3.30.360.10/                                     -0.840841
# ../CATH_data/2.80.10.50/                                      -0.595272
# ../CATH_data/3.30.450.20/                                     -0.751407
# ../CATH_data/2.60.40.420/                                     -0.807463
# ../CATH_data/1.25.40.10/                                       0.385863
# ../CATH_data/3.30.200.20/                                      0.265999
# ../CATH_data/3.40.47.10/                                      -0.828653
# ../CATH_data/2.40.10.10/                                      -0.170436
# ../CATH_data/2.40.50.40/                                      -0.460498
# ../CATH_data/3.90.190.10/                                      0.711821
# ../CATH_data/1.20.1050.10/                                    -0.828683
# ../CATH_data/2.30.110.10/                                     -0.381346
# ../CATH_data/3.40.50.150/                                     -0.503322
# ../CATH_data/3.10.100.10/                                     -0.257215
# ../CATH_data/3.60.15.10/                                      -0.398826
# ../CATH_data/1.10.600.10/                                     -0.727267
# ../CATH_data/3.40.50.300/                                     -0.595538
# ../CATH_data/2.40.50.140/                                     -0.425333
# ../CATH_data/3.30.530.20/                                     -0.796912
# ../CATH_data/2.60.40.1180/                                    -0.605153
# ../CATH_data/1.20.1260.10/                                    -0.735081
# ../CATH_data/2.30.30.100/                                     -0.813876
# ../CATH_data/3.20.20.140/                                     -0.543108
# ../CATH_data/2.60.120.10/                                     -0.618043
# ../CATH_data/3.10.450.50/                                     -0.496488
# ../CATH_data/3.40.630.30/                                     -0.335067
# ../CATH_data/2.30.30.40/                                    -303.467946
# ../CATH_data/3.20.20.80/                                      -0.377640
# ../CATH_data/3.20.20.120/                                     -0.731076
# ../CATH_data/1.20.5.170/                                       0.730139
# ../CATH_data/1.10.760.10/                                           NaN
# ../CATH_data/3.50.50.60/                                      -0.545357
# ../CATH_data/2.60.120.200/                                    -0.823846
# ../CATH_data/3.40.50.360/                                     -0.714379
# ../CATH_data/3.40.50.1000/                                    -0.600743
# ../CATH_data/3.90.550.10/                                     -0.437462
# ../CATH_data/3.30.40.10/                                       0.386608
# ../CATH_data/3.80.10.10/                                      -0.923525
# ../CATH_data/3.30.390.10/                                     -0.729731
# ../CATH_data/3.40.50.970/                                     -0.498546
# ../CATH_data/2.40.50.100/                                     -0.513666
# ../CATH_data/1.10.630.10/                                     -0.289309
# ../CATH_data/3.40.640.10/                                     -0.652239
# ../CATH_data/3.90.79.10/                                      -0.343507
# ../CATH_data/1.10.533.10/                                      0.900571
# ../CATH_data/3.90.226.10/                                     -0.522373
# ../CATH_data/3.30.450.40/                                     -0.092959
# ../CATH_data/3.40.50.1820/                                    -0.529717
# ../CATH_data/1.10.238.10/                                     -0.864855
#
#                                     clade  HOG
# ../CATH_data/1.10.490.10/   ../CATH_data/
# ../CATH_data/3.40.1190.20/  ../CATH_data/
# ../CATH_data/3.40.30.10/    ../CATH_data/
# ../CATH_data/3.40.50.720/   ../CATH_data/
# ../CATH_data/3.20.20.70/    ../CATH_data/
# ../CATH_data/3.90.180.10/   ../CATH_data/
# ../CATH_data/3.10.20.90/    ../CATH_data/
# ../CATH_data/3.40.50.880/   ../CATH_data/
# ../CATH_data/3.30.70.100/   ../CATH_data/
# ../CATH_data/1.10.8.60/     ../CATH_data/
# ../CATH_data/2.30.42.10/    ../CATH_data/
# ../CATH_data/3.30.360.10/   ../CATH_data/
# ../CATH_data/2.80.10.50/    ../CATH_data/
# ../CATH_data/3.30.450.20/   ../CATH_data/
# ../CATH_data/2.60.40.420/   ../CATH_data/
# ../CATH_data/1.25.40.10/    ../CATH_data/
# ../CATH_data/3.30.200.20/   ../CATH_data/
# ../CATH_data/3.40.47.10/    ../CATH_data/
# ../CATH_data/2.40.10.10/    ../CATH_data/
# ../CATH_data/2.40.50.40/    ../CATH_data/
# ../CATH_data/3.90.190.10/   ../CATH_data/
# ../CATH_data/1.20.1050.10/  ../CATH_data/
# ../CATH_data/2.30.110.10/   ../CATH_data/
# ../CATH_data/3.40.50.150/   ../CATH_data/
# ../CATH_data/3.10.100.10/   ../CATH_data/
# ../CATH_data/3.60.15.10/    ../CATH_data/
# ../CATH_data/1.10.600.10/   ../CATH_data/
# ../CATH_data/3.40.50.300/   ../CATH_data/
# ../CATH_data/2.40.50.140/   ../CATH_data/
# ../CATH_data/3.30.530.20/   ../CATH_data/
# ../CATH_data/2.60.40.1180/  ../CATH_data/
# ../CATH_data/1.20.1260.10/  ../CATH_data/
# ../CATH_data/2.30.30.100/   ../CATH_data/
# ../CATH_data/3.20.20.140/   ../CATH_data/
# ../CATH_data/2.60.120.10/   ../CATH_data/
# ../CATH_data/3.10.450.50/   ../CATH_data/
# ../CATH_data/3.40.630.30/   ../CATH_data/
# ../CATH_data/2.30.30.40/    ../CATH_data/
# ../CATH_data/3.20.20.80/    ../CATH_data/
# ../CATH_data/3.20.20.120/   ../CATH_data/
# ../CATH_data/1.20.5.170/    ../CATH_data/
# ../CATH_data/1.10.760.10/   ../CATH_data/
# ../CATH_data/3.50.50.60/    ../CATH_data/
# ../CATH_data/2.60.120.200/  ../CATH_data/
# ../CATH_data/3.40.50.360/   ../CATH_data/
# ../CATH_data/3.40.50.1000/  ../CATH_data/
# ../CATH_data/3.90.550.10/   ../CATH_data/
# ../CATH_data/3.30.40.10/    ../CATH_data/
# ../CATH_data/3.80.10.10/    ../CATH_data/
# ../CATH_data/3.30.390.10/   ../CATH_data/
# ../CATH_data/3.40.50.970/   ../CATH_data/
# ../CATH_data/2.40.50.100/   ../CATH_data/
# ../CATH_data/1.10.630.10/   ../CATH_data/
# ../CATH_data/3.40.640.10/   ../CATH_data/
# ../CATH_data/3.90.79.10/    ../CATH_data/
# ../CATH_data/1.10.533.10/   ../CATH_data/
# ../CATH_data/3.90.226.10/   ../CATH_data/
# ../CATH_data/3.30.450.40/   ../CATH_data/
# ../CATH_data/3.40.50.1820/  ../CATH_data/
# ../CATH_data/1.10.238.10/   ../CATH_data/
#
# [60 rows x 249 columns]

# %%
#add nsequences 
#ncoverage clade
#len sequence
#pdb pred quality
#rf dist
#resdf = resdf[resdf.clade == '/work/FAC/FBM/DBC/cdessim2/default/dmoi/datasets/Structure_Trees/Eumetazoa/' ]

print(len(tree_resdf))
# Out:
# 60

# %%
from matplotlib import pyplot as plt

for c1,c2 in itertools.combinations(refclols,2):    
    if 'sequence' in c1 or 'sequence' in c2:
        print(c1,c2)
        sns.scatterplot(tree_resdf, x = c1, y=c2 , alpha = .25 , s = 20 )
        from scipy.stats import wilcoxon
        print(tree_resdf[c1+'_'+c2+'_delta'].dropna().sum(), tree_resdf[c1+'_'+c2+'_delta_norm'].dropna().sum(),wilcoxon(tree_resdf[c1+'_'+c2+'_delta'].dropna()))
        maxval = tree_resdf[[c1, c2]].max().max()
        sns.lineplot(x = [0,maxval] , y = [0,maxval] , linestyle='--' , c = 'k')
        plt.show()
# Out:
# alntmscore_0_raw_struct_tree sequences
# 2427491.529305592 -46.941896091260155 WilcoxonResult(statistic=154.0, pvalue=2.1167271347612363e-08)
# alntmscore_0_exp_struct_tree sequences
# -7865.306077798612 -38.25306133446327 WilcoxonResult(statistic=14.0, pvalue=3.293683695279847e-11)
# alntmscore_1_exp_struct_tree sequences
# -7024.377253959364 -36.56707166506138 WilcoxonResult(statistic=21.0, pvalue=6.963035706847179e-11)
# fident_0_raw_struct_tree sequences
# -2406076633.0947113 -1992056.1260339178 WilcoxonResult(statistic=118.0, pvalue=4.432223720873952e-09)
# lddt_0_exp_struct_tree sequences
# -7216.191610794201 -35.02313629156543 WilcoxonResult(statistic=14.0, pvalue=3.293683695279847e-11)
# lddt_1_exp_struct_tree sequences
# -6826.358675722356 -33.826021809032 WilcoxonResult(statistic=17.0, pvalue=3.8245657805744056e-11)
# fident_0_exp_struct_tree sequences
# -6002.366145290082 -24.82534703477519 WilcoxonResult(statistic=35.0, pvalue=9.281672073789129e-11)
# lddt_1_raw_struct_tree sequences
# 117234.92603362995 -26.701818941906563 WilcoxonResult(statistic=134.0, pvalue=2.3222010179778082e-08)
# fident_1_raw_struct_tree sequences
# -101015.79095233355 -118.9684428341028 WilcoxonResult(statistic=455.0, pvalue=0.0007083224313063217)
# fident_1_exp_struct_tree sequences
# -5009.7931454149875 -20.76771742009566 WilcoxonResult(statistic=90.0, pvalue=1.252904940239322e-09)
# alntmscore_1_raw_struct_tree sequences
# 515.3101837141024 -32.9731107894815 WilcoxonResult(statistic=155.0, pvalue=3.587879114662353e-08)
# lddt_0_raw_struct_tree sequences
# -364950.5032265948 -330.2207238543582 WilcoxonResult(statistic=136.0, pvalue=2.538353192297811e-08)

# %%
sns.violinplot(tree_resdf[refclols] , cut = 0 )

# %%
#sns.violinplot(resdf['delta_norm'])
sns.violinplot(tree_resdf[['struct_tree.nwk.PP.nwk.rooted', 'sequences.aln.fst.nwk.rooted']] , cut = 0)
print(tree_resdf['delta'].sum() )
print(tree_resdf['delta_norm'].sum() )

# %%
sns.violinplot(tree_resdf['delta'])

# %%
#sub = resdf[['sequences.aln.fst.nwk.rooted' , 'struct_tree.nwk.PP.nwk.rooted' ]]
from matplotlib import pyplot as plt

for folder in tree_resdf.clade.unique():
    print(folder)
    sub = tree_resdf[tree_resdf.clade == folder]
    print(sub.mean())
    
    maxval = sub[['struct_tree.nwk.PP.nwk.rooted', 'sequences.aln.fst.nwk.rooted']].max().max()
    
    sns.scatterplot(sub, x = 'sequences.aln.fst.nwk.rooted', y='struct_tree.nwk.PP.nwk.rooted' , alpha = .25 , s=20 )
    
    sns.scatterplot(sub, x = 'sequences.aln.fst.nwk.rooted', y='core_tree.nwk.PP.nwk.rooted' , alpha = .25 , s=20 , c='r' )
    
    sns.lineplot(x = [0,maxval] , y = [0,maxval] , linestyle='--' , c = 'k')
    
    plt.show()
    sns.violinplot(sub[['struct_tree.nwk.PP.nwk.rooted', 'sequences.aln.fst.nwk.rooted', 'core_tree.nwk.PP.nwk.rooted']] , cut = 0 )
    plt.show()
    sns.violinplot(sub['delta'] , cut = 0 )
    plt.show()
    sns.violinplot(sub['delta_norm'] , cut = 0 )
    plt.show()
    
    print( sub.delta.sum(), wilcoxon(sub.delta))
    print( sub.delta_norm.sum(), wilcoxon(sub.delta_norm))
# Out:
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/datasets/Structure_Trees/Bacteria/
# struct_tree.nwk.PP.nwk.rooted    73.455099
# core_tree.nwk.PP.nwk.rooted      73.456621
# sequences.aln.fst.nwk.rooted     73.225266
# delta                             0.229833
# max                              75.098935
# delta_norm                        0.002770
# dtype: float64
# /tmp/25066229/ipykernel_3984039/1650548452.py:7: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(sub.mean())
# 151 WilcoxonResult(statistic=44422.5, pvalue=0.6178605003753332)
# 1.8197588925547938 WilcoxonResult(statistic=45208.5, pvalue=0.8506301919154431)
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/datasets/Structure_Trees/LUCA/
# struct_tree.nwk.PP.nwk.rooted    246.662026
# core_tree.nwk.PP.nwk.rooted      246.631864
# sequences.aln.fst.nwk.rooted     251.926527
# delta                             -5.264501
# max                              253.545244
# delta_norm                        -0.016798
# dtype: float64
# /tmp/25066229/ipykernel_3984039/1650548452.py:7: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(sub.mean())
# -6807 WilcoxonResult(statistic=161415.0, pvalue=1.0191735720945887e-44)
# -21.71950626692426 WilcoxonResult(statistic=200611.5, pvalue=2.8828553952996364e-25)
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/datasets/Structure_Trees/Eumetazoa/
# struct_tree.nwk.PP.nwk.rooted    369.116967
# core_tree.nwk.PP.nwk.rooted      369.157455
# sequences.aln.fst.nwk.rooted     375.817481
# delta                             -6.700514
# max                              377.863111
# delta_norm                        -0.016864
# dtype: float64
# /tmp/25066229/ipykernel_3984039/1650548452.py:7: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(sub.mean())
# -10426 WilcoxonResult(statistic=211659.0, pvalue=1.4457182537044683e-67)
# -26.240546664667058 WilcoxonResult(statistic=223131.5, pvalue=1.166157492999848e-61)
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/datasets/Structure_Trees/Chordata/
# struct_tree.nwk.PP.nwk.rooted    415.114738
# core_tree.nwk.PP.nwk.rooted      415.147379
# sequences.aln.fst.nwk.rooted     417.486647
# delta                             -2.371909
# max                              420.727992
# delta_norm                        -0.006058
# dtype: float64
# /tmp/25066229/ipykernel_3984039/1650548452.py:7: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(sub.mean())
# -2398 WilcoxonResult(statistic=100297.0, pvalue=1.217690342742138e-18)
# -6.124724663431841 WilcoxonResult(statistic=103588.0, pvalue=1.0809406721212726e-16)
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/datasets/Structure_Trees/Dikarya/
# struct_tree.nwk.PP.nwk.rooted    96.176796
# core_tree.nwk.PP.nwk.rooted      96.132597
# sequences.aln.fst.nwk.rooted     97.121547
# delta                            -0.944751
# max                              97.751381
# delta_norm                       -0.010116
# dtype: float64
# /tmp/25066229/ipykernel_3984039/1650548452.py:7: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(sub.mean())
# -171 WilcoxonResult(statistic=1682.0, pvalue=9.93582458689547e-05)
# -1.830930182247622 WilcoxonResult(statistic=1695.5, pvalue=0.00013130595030209636)
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/datasets/Structure_Trees/Fungi/
# struct_tree.nwk.PP.nwk.rooted    79.893939
# core_tree.nwk.PP.nwk.rooted      79.893939
# sequences.aln.fst.nwk.rooted     81.265152
# delta                            -1.371212
# max                              82.143939
# delta_norm                       -0.017044
# dtype: float64
# /tmp/25066229/ipykernel_3984039/1650548452.py:7: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(sub.mean())
# -181 WilcoxonResult(statistic=1656.0, pvalue=0.00018837509630559608)
# -2.249847413229308 WilcoxonResult(statistic=1731.5, pvalue=0.0005018194050568486)
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/datasets/Structure_Trees/Bilateria/
# struct_tree.nwk.PP.nwk.rooted    377.915736
# core_tree.nwk.PP.nwk.rooted      377.929949
# sequences.aln.fst.nwk.rooted     382.732995
# delta                             -4.817259
# max                              384.832487
# delta_norm                        -0.011454
# dtype: float64
# /tmp/25066229/ipykernel_3984039/1650548452.py:7: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(sub.mean())
# -4745 WilcoxonResult(statistic=72925.5, pvalue=1.5295405102348116e-37)
# -11.282260028399016 WilcoxonResult(statistic=76060.5, pvalue=8.657553676387303e-35)
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/datasets/Structure_Trees/Eukaryota/
# struct_tree.nwk.PP.nwk.rooted    490.977792
# core_tree.nwk.PP.nwk.rooted      491.027919
# sequences.aln.fst.nwk.rooted     503.813452
# delta                            -12.835660
# max                              505.878490
# delta_norm                        -0.022476
# dtype: float64
# /tmp/25066229/ipykernel_3984039/1650548452.py:7: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(sub.mean())
# -40458 WilcoxonResult(statistic=605963.5, pvalue=1.4824048824815878e-217)
# -70.84305446313886 WilcoxonResult(statistic=704917.5, pvalue=8.810072571382074e-187)

# %%
#construct structure and sequence feature dataset

def ret_description(vec , label = ''):
    return { label+'_mean': np.mean(vec) , label+'_max': np.amax(vec) , label+'_min': np.amin(vec) ,label+'_var': np.var(vec) }

allfolders = glob.glob(cladefolders)
dfs = []
print(allfolders)
for clade in allfolders:
    print(clade)
    res = {}
    folders = glob.glob(clade + '*/' )
    for folder in folders:
        if os.path.isfile(folder + 'plddt.json' ) and os.path.isfile(folder + 'sequence_dataset.csv' ) :
            plddt_df = pd.read_json(folder + 'plddt.json').T
            if len(plddt_df)>0:
                try:
                    plddt_df.columns = 'nobs,minmax,mean,variance,skewness,kurtosis'.split(',')
                    plddt_df['min'] = plddt_df.minmax.map( lambda r: r[0] )
                    plddt_df['max'] = plddt_df.minmax.map( lambda r: r[1] )
                    res[folder] = {}
                    for col in ['nobs', 'min' , 'max' , 'mean' , 'variance' , 'skewness' , 'kurtosis' ]:
                        descriptors = ret_description(plddt_df[col] , label = col)
                        for l in descriptors:
                            res[folder][l] = descriptors[l]
                    #add in some descriptors of the taxonomic spread and sequence set
                    seqdf = pd.read_csv(folder+'sequence_dataset.csv' )
                    res[folder]['nprots'] = len(seqdf)
                    cladesets = [ set(l.split(',')) for l in  seqdf['Taxonomic lineage (Ids)'] ]
                    union_all = cladesets[0]
                    intersection_all = cladesets[0]
                    for c in cladesets:
                        union_all = union_all.union(c)
                        intersection_all.intersection(c)
                    res[folder]['n_clades'] = len(union_all)
                    res[folder]['inter_clades'] = len(intersection_all)
                    res[folder]['inter/nc'] =  res[folder]['inter_clades'] /  res[folder]['n_clades'] 
                    res[folder]['nc/np'] = res[folder]['nprots'] / res[folder]['n_clades']
                except:
                    pass
    resdf = pd.DataFrame.from_dict(res, orient = 'index')
    dfs.append(resdf)
seqset_resdf = pd.concat(dfs)
# Out:
# ['/work/FAC/FBM/DBC/cdessim2/default/dmoi/datasets/Structure_Trees/Bacteria/', '/work/FAC/FBM/DBC/cdessim2/default/dmoi/datasets/Structure_Trees/LUCA/', '/work/FAC/FBM/DBC/cdessim2/default/dmoi/datasets/Structure_Trees/Euteleostomi/', '/work/FAC/FBM/DBC/cdessim2/default/dmoi/datasets/Structure_Trees/Eumetazoa/', '/work/FAC/FBM/DBC/cdessim2/default/dmoi/datasets/Structure_Trees/Chordata/', '/work/FAC/FBM/DBC/cdessim2/default/dmoi/datasets/Structure_Trees/Tetrapoda/', '/work/FAC/FBM/DBC/cdessim2/default/dmoi/datasets/Structure_Trees/Opisthokonta/', '/work/FAC/FBM/DBC/cdessim2/default/dmoi/datasets/Structure_Trees/Dikarya/', '/work/FAC/FBM/DBC/cdessim2/default/dmoi/datasets/Structure_Trees/Fungi/', '/work/FAC/FBM/DBC/cdessim2/default/dmoi/datasets/Structure_Trees/Bilateria/', '/work/FAC/FBM/DBC/cdessim2/default/dmoi/datasets/Structure_Trees/Eukaryota/']
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/datasets/Structure_Trees/Bacteria/
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/datasets/Structure_Trees/LUCA/
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/datasets/Structure_Trees/Euteleostomi/
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/datasets/Structure_Trees/Eumetazoa/
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/datasets/Structure_Trees/Chordata/
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/datasets/Structure_Trees/Tetrapoda/
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/datasets/Structure_Trees/Opisthokonta/
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/datasets/Structure_Trees/Dikarya/
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/datasets/Structure_Trees/Fungi/
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/datasets/Structure_Trees/Bilateria/
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/datasets/Structure_Trees/Eukaryota/

# %%
print(seqset_resdf)
seqset_resdf.to_csv('structure_and_sequence_qcmetrics.csv')
# Out:
#                                                       nobs_mean  nobs_max  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...   807.250000       985
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...   521.944444       811
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...   401.434783       516
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    64.357143        71
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...   204.133333       215
# ...                                                         ...       ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  1041.034884      1191
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...   446.782609       581
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...   351.106061       480
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...   384.966102       506
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...   890.472222      1124
#
#                                                     nobs_min     nobs_var  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       642  9765.520833
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       447  5585.830247
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       277  1294.463138
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...        56    29.086735
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       191    56.382222
# ...                                                      ...          ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       667  3364.382504
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       290  6449.561437
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       187  3556.579660
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       274  2674.575122
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       557  8787.915895
#
#                                                      min_mean  min_max  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  34.624167    53.28
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  33.694444    49.47
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  35.808913    47.16
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  67.612143    74.96
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  37.811333    60.66
# ...                                                       ...      ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  26.432907    49.84
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  27.608261    35.90
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  27.326364    60.81
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  27.073898    33.50
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  31.714167    62.62
#
#                                                     min_min     min_var  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    24.20   60.249258
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    23.28   35.850047
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    28.72   24.900805
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    61.63   17.622931
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    20.38  103.666985
# ...                                                     ...         ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    20.27   35.795802
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    24.58    6.491693
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    19.63   65.113332
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    21.31    8.618786
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    19.72  171.468774
#
#                                                      max_mean  max_max  ...  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  98.885000    98.95  ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  98.288333    98.78  ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  98.446957    98.88  ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  96.832143    97.92  ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  92.832667    98.85  ...
# ...                                                       ...      ...  ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  98.867791    98.96  ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  98.164783    98.50  ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  98.747424    98.89  ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  97.897119    98.86  ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  98.943611    99.00  ...
#
#                                                     skewness_var  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0.676739
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0.436234
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0.387872
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0.391886
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      1.933084
# ...                                                          ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0.622155
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0.194253
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0.772692
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0.291286
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      1.928180
#
#                                                     kurtosis_mean  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      19.837862
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       5.764221
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       7.879371
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       4.578632
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       8.192775
# ...                                                           ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      11.438603
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      -1.477518
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       1.470316
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      -0.555410
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      18.847422
#
#                                                     kurtosis_max  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     34.363297
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     12.669195
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     21.380946
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     14.923462
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     21.343251
# ...                                                          ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     27.295166
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0.096212
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     35.943302
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      1.861041
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     35.672303
#
#                                                     kurtosis_min  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      9.844506
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     -1.358798
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0.084182
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     -0.079853
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     -0.571496
# ...                                                          ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0.971629
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     -1.811054
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     -1.774900
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     -1.762139
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      1.241103
#
#                                                     kurtosis_var  nprots  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     57.878212      12
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     12.864899      18
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     17.109750      46
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     14.677287      14
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     46.462987      15
# ...                                                          ...     ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     41.532549      87
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0.239959      23
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     34.498932      66
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      1.096213      59
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    143.677776      36
#
#                                                     n_clades  inter_clades  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      43.0          10.0
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      43.0          11.0
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      97.0           8.0
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      83.0           8.0
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      48.0          11.0
# ...                                                      ...           ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     378.0          30.0
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     164.0          13.0
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     211.0          13.0
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     292.0          30.0
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     247.0          30.0
#
#                                                     inter/nc     nc/np
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.232558  0.279070
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.255814  0.418605
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.082474  0.474227
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.096386  0.168675
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.229167  0.312500
# ...                                                      ...       ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.079365  0.230159
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.079268  0.140244
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.061611  0.312796
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.102740  0.202055
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.121457  0.145749
#
# [13424 rows x 33 columns]

# %%
#add to the tree comparison data
tree_resdf = tree_resdf.merge( seqset_resdf , left_index = True, right_index = True, how = 'inner' )
print(tree_resdf)
# Out:
#                                                     struct_tree.nwk.PP.nwk.rooted  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                             52
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                             76
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                            141
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                             33
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                             59
# ...                                                                           ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                           1022
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                            123
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                            642
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                            660
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                            462
#
#                                                     core_tree.nwk.PP.nwk.rooted  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                           52
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                           76
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                          141
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                           33
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                           59
# ...                                                                         ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                         1022
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                          123
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                          642
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                          660
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                          462
#
#                                                     sequences.aln.fst.nwk.rooted  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                            47
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                            76
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                           140
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                            33
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                            42
# ...                                                                          ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                          1054
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                           137
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                           679
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                           686
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...                           461
#
#                                                     delta   max  delta_norm  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      5    52    0.096154
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0    76    0.000000
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      1   141    0.007092
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0    33    0.000000
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     17    59    0.288136
# ...                                                   ...   ...         ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    -32  1054   -0.030361
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    -14   137   -0.102190
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    -37   679   -0.054492
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    -26   686   -0.037901
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      1   462    0.002165
#
#                                                                                                 clade  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  /work/FAC/FBM/DBC/cdessim2/default/dmoi/datase...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  /work/FAC/FBM/DBC/cdessim2/default/dmoi/datase...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  /work/FAC/FBM/DBC/cdessim2/default/dmoi/datase...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  /work/FAC/FBM/DBC/cdessim2/default/dmoi/datase...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  /work/FAC/FBM/DBC/cdessim2/default/dmoi/datase...
# ...                                                                                               ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  /work/FAC/FBM/DBC/cdessim2/default/dmoi/datase...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  /work/FAC/FBM/DBC/cdessim2/default/dmoi/datase...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  /work/FAC/FBM/DBC/cdessim2/default/dmoi/datase...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  /work/FAC/FBM/DBC/cdessim2/default/dmoi/datase...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  /work/FAC/FBM/DBC/cdessim2/default/dmoi/datase...
#
#                                                    HOG    nobs_mean  nobs_max  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       807.250000       985
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       521.944444       811
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       401.434783       516
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...        64.357143        71
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       204.133333       215
# ...                                                 ..          ...       ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      1041.034884      1191
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       446.782609       581
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       351.106061       480
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       384.966102       506
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       890.472222      1124
#
#                                                     ...  skewness_var  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  ...      0.676739
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  ...      0.436234
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  ...      0.387872
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  ...      0.391886
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  ...      1.933084
# ...                                                 ...           ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  ...      0.622155
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  ...      0.194253
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  ...      0.772692
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  ...      0.291286
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  ...      1.928180
#
#                                                     kurtosis_mean  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      19.837862
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       5.764221
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       7.879371
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       4.578632
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       8.192775
# ...                                                           ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      11.438603
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      -1.477518
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...       1.470316
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      -0.555410
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      18.847422
#
#                                                     kurtosis_max  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     34.363297
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     12.669195
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     21.380946
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     14.923462
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     21.343251
# ...                                                          ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     27.295166
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0.096212
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     35.943302
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      1.861041
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     35.672303
#
#                                                     kurtosis_min  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      9.844506
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     -1.358798
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0.084182
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     -0.079853
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     -0.571496
# ...                                                          ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0.971629
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     -1.811054
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     -1.774900
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     -1.762139
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      1.241103
#
#                                                     kurtosis_var  nprots  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     57.878212      12
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     12.864899      18
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     17.109750      46
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     14.677287      14
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     46.462987      15
# ...                                                          ...     ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     41.532549      87
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      0.239959      23
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     34.498932      66
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      1.096213      59
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...    143.677776      36
#
#                                                     n_clades  inter_clades  \
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      43.0          10.0
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      43.0          11.0
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      97.0           8.0
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      83.0           8.0
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...      48.0          11.0
# ...                                                      ...           ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     378.0          30.0
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     164.0          13.0
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     211.0          13.0
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     292.0          30.0
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...     247.0          30.0
#
#                                                     inter/nc     nc/np
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.232558  0.279070
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.255814  0.418605
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.082474  0.474227
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.096386  0.168675
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.229167  0.312500
# ...                                                      ...       ...
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.079365  0.230159
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.079268  0.140244
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.061611  0.312796
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.102740  0.202055
# /work/FAC/FBM/DBC/cdessim2/default/dmoi/dataset...  0.121457  0.145749
#
# [8967 rows x 41 columns]

# %%
print(tree_resdf.columns)
# Out:
# Index(['struct_tree.nwk.PP.nwk.rooted', 'core_tree.nwk.PP.nwk.rooted',
#        'sequences.aln.fst.nwk.rooted', 'delta', 'max', 'delta_norm', 'clade',
#        'HOG', 'nobs_mean', 'nobs_max', 'nobs_min', 'nobs_var', 'min_mean',
#        'min_max', 'min_min', 'min_var', 'max_mean', 'max_max', 'max_min',
#        'max_var', 'mean_mean', 'mean_max', 'mean_min', 'mean_var',
#        'variance_mean', 'variance_max', 'variance_min', 'variance_var',
#        'skewness_mean', 'skewness_max', 'skewness_min', 'skewness_var',
#        'kurtosis_mean', 'kurtosis_max', 'kurtosis_min', 'kurtosis_var',
#        'nprots', 'n_clades', 'inter_clades', 'inter/nc', 'nc/np'],
#       dtype='object')

# %%
#try to predict the delta using these features w gradient boosted trees
#try to predict the RF distance as well

import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, ensemble
from sklearn.inspection import permutation_importance
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
X, y = tree_resdf[['nobs_mean', 'nobs_max',
       'nobs_min', 'nobs_var', 'min_mean', 'min_max', 'min_min', 'min_var',
       'max_mean', 'max_max', 'max_min', 'max_var', 'mean_mean', 'mean_max',
       'mean_min', 'mean_var', 'variance_mean', 'variance_max', 'variance_min',
       'variance_var', 'skewness_mean', 'skewness_max', 'skewness_min',
       'skewness_var', 'kurtosis_mean', 'kurtosis_max', 'kurtosis_min',
       'kurtosis_var', 'nprots', 'n_clades', 'inter_clades', 'inter/nc',
       'nc/np']], tree_resdf.delta_norm

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.1, random_state=13
)

params = {
    "n_estimators": 500,
    "max_depth": 4,
    "min_samples_split": 5,
    "learning_rate": 0.01,
    "loss": "squared_error",
}


reg = ensemble.GradientBoostingRegressor(**params)
reg.fit(X_train, y_train)

mse = mean_squared_error(y_test, reg.predict(X_test))
print("The mean squared error (MSE) on test set: {:.4f}".format(mse))

test_score = np.zeros((params["n_estimators"],), dtype=np.float64)
for i, y_pred in enumerate(reg.staged_predict(X_test)):
    test_score[i] = mean_squared_error(y_test, y_pred)
# Out:
# The mean squared error (MSE) on test set: 0.0042

# %%
fig = plt.figure(figsize=(6, 6))
plt.subplot(1, 1, 1)
plt.title("Deviance")
plt.plot(
    np.arange(params["n_estimators"]) + 1,
    reg.train_score_,
    "b-",
    label="Training Set Deviance",
)
plt.plot(
    np.arange(params["n_estimators"]) + 1, test_score, "r-", label="Test Set Deviance"
)
plt.legend(loc="upper right")
plt.xlabel("Boosting Iterations")
plt.ylabel("Deviance")
fig.tight_layout()
plt.show()

# %%
feature_importance = reg.feature_importances_
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + 0.5
fig = plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.barh(pos, feature_importance[sorted_idx], align="center")
plt.yticks(pos, np.array(X.columns)[sorted_idx])
plt.title("Feature Importance (MDI)")

result = permutation_importance(
    reg, X_test, y_test, n_repeats=10, random_state=42, n_jobs=2
)
sorted_idx = result.importances_mean.argsort()
plt.subplot(1, 2, 2)
plt.boxplot(
    result.importances[sorted_idx].T,
    vert=False,
    labels=np.array(X.columns)[sorted_idx],
)
plt.title("Permutation Importance (test set)")
fig.tight_layout()
plt.show()
